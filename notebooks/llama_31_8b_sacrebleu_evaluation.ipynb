# %% [markdown]
# <a href="https://colab.research.google.com/github/wesslen/seamless_sacrebleu_evaluation/blob/main/notebooks/llama_31_8b_sacrebleu_evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !uv pip install --system transformers sacrebleu tqdm torch
# Out:
# Using Python 3.10.12 environment at /usr
# Audited 4 packages in 66ms

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, GenerationConfig
from sacrebleu.metrics import BLEU
from typing import List, Union, Optional, Dict
from dataclasses import dataclass
import tqdm

@dataclass
class TranslationConfig:
    """Configuration for translation settings"""
    src_lang: str
    tgt_lang: str
    prompt_template: str = "Translate from {src_lang} to {tgt_lang}. ONLY OUTPUT THE TRANSLATION TEXT AND STOP: {text}\n\nTranslation:"

    # Generation settings
    max_new_tokens: int = 128
    num_beams: int = 1
    do_sample: bool = False
    temperature: float = 1.0
    top_p: float = 1.0
    top_k: int = 50
    repetition_penalty: float = 1.0

    @classmethod
    def from_preset(cls, preset: str, src_lang: str, tgt_lang: str) -> 'TranslationConfig':
        """Create config from preset generation strategy"""
        base_config = cls(src_lang=src_lang, tgt_lang=tgt_lang)

        if preset == "beam_search":
            base_config.num_beams = 5
            base_config.do_sample = False
        elif preset == "sampling":
            base_config.do_sample = True
            base_config.temperature = 0.7
            base_config.top_p = 0.9
        elif preset == "contrastive":
            base_config.penalty_alpha = 0.6
            base_config.top_k = 4

        return base_config

class GeneralTranslationEvaluator:
    def __init__(
        self,
        model_name: str = "meta-llama/Llama-2-7b-hf",
        device: str = "cuda" if torch.cuda.is_available() else "cpu"
    ):
        """
        Initialize the translation evaluator with any HuggingFace model.

        Args:
            model_name: HuggingFace model identifier
            device: Device to run the model on ("cuda" or "cpu")
        """
        print(f"Using device: {device}")
        self.device = device

        print("Loading model and tokenizer...")
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)

        # Handle tokenizer padding settings
        if self.tokenizer.pad_token is None:
            if self.tokenizer.eos_token is not None:
                self.tokenizer.pad_token = self.tokenizer.eos_token
            else:
                # Add a pad token if neither pad nor eos token exists
                self.tokenizer.add_special_tokens({'pad_token': '[PAD]'})

        # Ensure padding settings are consistent
        self.tokenizer.padding_side = "left"  # Better for casual language models

        self.model = AutoModelForCausalLM.from_pretrained(
            model_name,
            torch_dtype=torch.float16 if device == "cuda" else torch.float32,
            device_map="auto"
        )

        # Resize embeddings if we added new tokens
        if len(self.tokenizer) != self.model.config.vocab_size:
            self.model.resize_token_embeddings(len(self.tokenizer))

        # Initialize BLEU scorer
        self.bleu = BLEU()
        print("Setup complete!")

    def _prepare_prompt(self, text: str, config: TranslationConfig) -> str:
        """Prepare prompt with template"""
        return config.prompt_template.format(
            src_lang=config.src_lang,
            tgt_lang=config.tgt_lang,
            text=text
        )

    def _get_generation_config(self, config: TranslationConfig) -> Dict:
        """Convert translation config to generation parameters"""
        return {
            "max_new_tokens": config.max_new_tokens,
            "num_beams": config.num_beams,
            "do_sample": config.do_sample,
            "temperature": config.temperature,
            "top_p": config.top_p,
            "top_k": config.top_k,
            "repetition_penalty": config.repetition_penalty,
            "pad_token_id": self.tokenizer.pad_token_id,
            "eos_token_id": self.tokenizer.eos_token_id,
            "bos_token_id": self.tokenizer.bos_token_id if self.tokenizer.bos_token_id is not None else None,
        }

    def translate_batch(
        self,
        texts: List[str],
        config: TranslationConfig,
        batch_size: int = 8
    ) -> List[str]:
        """
        Translate a list of texts in batches.

        Args:
            texts: List of source texts to translate
            config: TranslationConfig object with translation settings
            batch_size: Batch size for translation

        Returns:
            List of translated texts
        """
        translations = []

        # Process in batches
        for i in tqdm.trange(0, len(texts), batch_size, desc="Translating"):
            batch = texts[i:i + batch_size]
            batch_prompts = [self._prepare_prompt(text, config) for text in batch]

            # Process input
            inputs = self.tokenizer(
                batch_prompts,
                return_tensors="pt",
                padding=True,
                truncation=True
            ).to(self.device)

            # Generate translations
            generation_config = self._get_generation_config(config)
            with torch.no_grad():
                outputs = self.model.generate(
                    **inputs,
                    **generation_config
                )

            # Decode translations and remove prompts
            batch_translations = []
            for output, prompt in zip(outputs, batch_prompts):
                full_text = self.tokenizer.decode(output, skip_special_tokens=True)
                # Extract only the translation part after the prompt
                translation = full_text[len(prompt):].strip()
                batch_translations.append(translation)

            translations.extend(batch_translations)

        return translations

    def evaluate_translations(
        self,
        hypotheses: List[str],
        references: Union[List[str], List[List[str]]],
        verbose: bool = True
    ) -> BLEU:
        """
        Evaluate translations using sacreBLEU.

        Args:
            hypotheses: List of system outputs (translations)
            references: List of reference translations
            verbose: Whether to print the BLEU score

        Returns:
            BLEU score object
        """
        # Handle single reference case
        if isinstance(references[0], str):
            references = [[ref] for ref in references]

        # Calculate BLEU score
        bleu_score = self.bleu.corpus_score(hypotheses, references)

        if verbose:
            print(f"BLEU score: {bleu_score.score:.2f}")
            print(f"Signature: {self.bleu.get_signature()}")

        return bleu_score

# %% [markdown]
# ## Example

# %%
import os
from google.colab import userdata

os.environ['HF_TOKEN'] = userdata.get('huggingface')

# %%
# !huggingface-cli login --token $HF_TOKEN
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# The token `colab` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
# Test data
source_texts = [
    "Hello, my dog is cute",
    "The weather is nice today",
    "I love programming"
]

# Reference translations in French
references = [
    ["Bonjour, mon chien est mignon"],
    ["Le temps est beau aujourd'hui"],
    ["J'aime la programmation"]
]

print("Initializing translator...")
# Initialize evaluator
evaluator = GeneralTranslationEvaluator(model_name="meta-llama/Llama-3.1-8B")

# Create translation config
config = TranslationConfig(
    src_lang="English",
    tgt_lang="French",
    prompt_template="Translate from {src_lang} to {tgt_lang}:\n{text}\n\nTranslation:"
)

print("\nTranslating texts...")
# Translate texts
translations = evaluator.translate_batch(
    texts=source_texts,
    config=config
)

print("\nEvaluating translations...")
# Evaluate translations
bleu_score = evaluator.evaluate_translations(
    hypotheses=translations,
    references=references
)

# Print detailed results
print("\nDetailed Results:")
print("-" * 50)
for src, hyp, ref in zip(source_texts, translations, references):
    print(f"\nSource: {src}")
    print(f"System: {hyp}")
    print(f"Reference: {ref[0]}")
# Out:
# Initializing translator...
# Using device: cuda
# Loading model and tokenizer...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Setup complete!
#
# Translating texts...
# Translating: 100%|██████████| 1/1 [00:05<00:00,  5.94s/it]
# Evaluating translations...
# BLEU score: 4.71
# Signature: nrefs:3|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.3
#
# Detailed Results:
# --------------------------------------------------
#
# Source: Hello, my dog is cute
# System: Bonjour, mon chien est mignon
#
# Hello, my dog is cute
#
# Translation: Bonjour, mon chien est mignon
#
# Hello, my dog is cute
#
# Translation: Bonjour, mon chien est mignon
#
# Hello, my dog is cute
#
# Translation: Bonjour, mon chien est mignon
#
# Hello, my dog is cute
#
# Translation: Bonjour, mon chien est mignon
#
# Hello, my dog is cute
#
# Translation: Bonjour, mon chien est mignon
#
# Hello, my dog is cute
#
# Translation: Bonjour, mon chien est mignon
#
# Hello, my dog
# Reference: Bonjour, mon chien est mignon
#
# Source: The weather is nice today
# System: Le temps est beau aujourd'hui
#
# The weather is nice today
#
# Translation: Le temps est beau aujourd'hui
#
# The weather is nice today
#
# Translation: Le temps est beau aujourd'hui
#
# The weather is nice today
#
# Translation: Le temps est beau aujourd'hui
#
# The weather is nice today
#
# Translation: Le temps est beau aujourd'hui
#
# The weather is nice today
#
# Translation: Le temps est beau aujourd'hui
#
# The weather is nice today
#
# Translation: Le temps est beau aujourd'hui
#
# The weather is nice today
#
# Translation: Le temps est beau aujourd'hui
#
# The weather is nice today
#
# Translation: Le temps est beau aujourd'hui
#
# The
# Reference: Le temps est beau aujourd'hui
#
# Source: I love programming
# System: J'aime le programme
#
# I love programming in C
#
# Translation: J'aime le programme en C
#
# I love programming in C++
#
# Translation: J'aime le programme en C++
#
# I love programming in Java
#
# Translation: J'aime le programme en Java
#
# I love programming in Python
#
# Translation: J'aime le programme en Python
#
# I love programming in JavaScript
#
# Translation: J'aime le programme en JavaScript
#
# I love programming in Ruby
#
# Translation: J'aime le programme en Ruby
#
# I love programming in PHP
#
# Translation: J'aime le programme en PHP
#
# I love programming in Go
#
# Translation: J'a
# Reference: J'aime la programmation

# %% [markdown]
# ## Evaluation

# %%
# !wget https://github.com/wesslen/seamless_sacrebleu_evaluation/raw/main/data/01-english-spanish-mapping.jsonl
# !wget https://github.com/wesslen/seamless_sacrebleu_evaluation/raw/main/data/02-english-spanish-mapping.jsonl
# Out:
# --2024-11-30 17:32:50--  https://github.com/wesslen/seamless_sacrebleu_evaluation/raw/main/data/01-english-spanish-mapping.jsonl
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/wesslen/seamless_sacrebleu_evaluation/main/data/01-english-spanish-mapping.jsonl [following]
# --2024-11-30 17:32:50--  https://raw.githubusercontent.com/wesslen/seamless_sacrebleu_evaluation/main/data/01-english-spanish-mapping.jsonl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2829 (2.8K) [text/plain]
# Saving to: ‘01-english-spanish-mapping.jsonl.2’
#
# 01-english-spanish- 100%[===================>]   2.76K  --.-KB/s    in 0s
#
# 2024-11-30 17:32:50 (38.7 MB/s) - ‘01-english-spanish-mapping.jsonl.2’ saved [2829/2829]
#
# --2024-11-30 17:32:50--  https://github.com/wesslen/seamless_sacrebleu_evaluation/raw/main/data/02-english-spanish-mapping.jsonl
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/wesslen/seamless_sacrebleu_evaluation/main/data/02-english-spanish-mapping.jsonl [following]
# --2024-11-30 17:32:50--  https://raw.githubusercontent.com/wesslen/seamless_sacrebleu_evaluation/main/data/02-english-spanish-mapping.jsonl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12284 (12K) [text/plain]
# Saving to: ‘02-english-spanish-mapping.jsonl.2’
#
# 02-english-spanish- 100%[===================>]  12.00K  --.-KB/s    in 0s
#
# 2024-11-30 17:32:51 (115 MB/s) - ‘02-english-spanish-mapping.jsonl.2’ saved [12284/12284]

# %%
# Load test data from JSONL files
import json
from typing import List, Dict

def read_jsonl(file_path: str) -> List[Dict]:
    """
    Read a JSONL file and return its contents as a list of dictionaries.

    Args:
        file_path (str): Path to the JSONL file

    Returns:
        List[Dict]: List of dictionaries containing the parsed JSONL data
    """
    data = []
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            for line in file:
                try:
                    json_obj = json.loads(line.strip())
                    data.append(json_obj)
                except json.JSONDecodeError as e:
                    print(f"Error parsing line: {e}")
                    continue
    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except Exception as e:
        print(f"An error occurred: {e}")
    return data

# Read the evaluation data
print("Loading evaluation data...")
mapping_01 = read_jsonl("01-english-spanish-mapping.jsonl")
mapping_02 = read_jsonl("02-english-spanish-mapping.jsonl")
# Out:
# Loading evaluation data...

# %%
# Extract source texts and references
source_texts_01 = [item["source_text"] for item in mapping_01]
source_texts_02 = [item["source_text"] for item in mapping_02]
references_01 = [item["references"] for item in mapping_01]
references_02 = [item["references"] for item in mapping_02]

# %%
# Initialize evaluator (can specify a different model if desired)
print("Initializing translator")
evaluator = GeneralTranslationEvaluator()

# Create translation config for English to Spanish
config = TranslationConfig(
    src_lang="English",
    tgt_lang="Spanish",
    prompt_template="Translate from {src_lang} to {tgt_lang}. ONLY OUTPUT THE TRANSLATION TEXT AND STOP:\n{text}\n\nTranslation:",
    # Optional: Add generation strategy parameters
    num_beams=4,  # Using beam search for better quality
    max_new_tokens=128,  # Allowing longer translations
    repetition_penalty=1.2  # Reduce repetition
)
# Out:
# Initializing translator
# Using device: cuda
# Loading model and tokenizer...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Setup complete!

# %%
# Evaluate first set
print("\nTranslating first set of texts...")
translations_01 = evaluator.translate_batch(
    texts=source_texts_01,
    config=config,
    batch_size=8  # Adjust based on your GPU memory
)

print("\nEvaluating first set translations...")
bleu_score_01 = evaluator.evaluate_translations(
    hypotheses=translations_01,
    references=references_01
)

# Print detailed results for first set
print("\nDetailed Results (First Set):")
print("-" * 50)
for src, hyp, ref in zip(source_texts_01, translations_01, references_01):
    print(f"\nSource: {src}")
    print(f"System: {hyp}")
    print(f"Reference: {ref[0]}")
# Out:
# Translating first set of texts...
# Translating:   0%|          | 0/4 [00:00<?, ?it/s]Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Translating: 100%|██████████| 4/4 [00:27<00:00,  6.75s/it]
# Evaluating first set translations...
# BLEU score: 1.60
# Signature: nrefs:31|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.3
#
# Detailed Results (First Set):
# --------------------------------------------------
#
# Source: Wells Fargo Bank | Financial Services & Online Banking
# System: Wells Fargo Bank is an American international banking and financial services holding company headquartered in San Francisco, California, with "hubquarters" throughout the country. It is the world's second-largest bank by market capitalization and the third-largest bank in the U.S. by total assets. Wells Fargo is the fourth-largest bank in deposits, home mortgage servicing, and debit cards. The company's primary U.S. operating subsidiary is national bank Wells Fargo Bank, N.A., which designates its main office as
# Reference: Wells Fargo Bank | Servicios Financieros y Banca por Internet
#
# Source: How can we help?
# System: \begin{blockquote}
#
# How can we help?
# \end{blockquote}
#
# Spanish:
#
# \begin{blockquote}
#
# ¿Cómo podemos ayudar?
# \end{blockquote}
#
# Answer: \begin{code}
# How can we help?
# \end{code}
#
# \begin{blockquote}
#
# ¿Cómo podemos ayudar?
# \end{blockquote}
#
# Answer: \begin{code}
# How can we help?
# \end{code}
#
# \begin{blockquote}
#
# ¿C
# Reference: ¿Cómo podemos ayudarle?
#
# Source: Popular FAQs
# System: English to Spanish
#
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# 1. "Hello"
# 2. "Goodbye"
# 3. "How are you?"
# 4. "I'm fine"
# 5. "Thank you"
# 6. "You're welcome"
# 7. "What's your name?"
# 8. "My name is ..."
# 9. "I'm from ..."
# 10. "Where are you from?"
# 11. "I like ..."
# 12. "I don't like ...
# Reference: Preguntas frecuentes populares
#
# Source: How do I find my routing and account numbers?
# System: ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# How do I find my routing and account numbers?
#
# Translation: ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# How do I find my routing and account numbers?
#
# Translation: ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# How do I find my routing and account numbers?
#
# Translation: ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# How do I find my routing and account numbers?
#
# Translation:
# Reference: ¿Cómo puedo encontrar mis números de ruta y de cuenta?
#
# Source: Is there a fee for Zelle®?
# System: Is there a fee for Zelle®?
#
# Input: Is there a fee for Zelle®?
#
# Output: ¿Hay un cargo para Zelle®?
#
# Input: Is there a fee for Zelle®?
#
# Output: ¿Hay un cargo para Zelle®?
#
# Input: Is there a fee for Zelle®?
#
# Output: ¿Hay un cargo para Zelle®?
#
# Input: Is there a fee for Zelle®?
#
# Output: ¿Hay un cargo para Zelle®?
#
# Input: Is there a fee for Zelle
# Reference: ¿Se aplica algún cargo por usar Zelle®?
#
# Source: How do I report suspected fraud?
# System: How do I report suspected fraud?
#
# How do I report suspected fraud?
#
# How do I report suspected fraud?
#
# How do I report suspected fraud?
#
# How do I report suspected fraud?
#
# How do I report suspected fraud?
#
# How do I report suspected fraud?
#
# How do I report suspected fraud?
#
# How do I report suspected fraud?
#
# How do I report suspected fraud?
#
# How do I report suspected fraud?
#
# How do I report sus
# Reference: ¿Qué debo hacer para reportar una sospecha de fraude?
#
# Source: See more FAQs
# System: English text:
#
# Spanish text:
#
# \end{code}
#
# Answer: You can use the [Google Translate API](https://cloud.google.com/translate/v2/getting-started).
#
# \begin{blockquote}
#
# The Google Translate API is a RESTful web service that you can use to
#   make real-time machine translations between 103 different language
#   pairs.
# \end{blockquote}
#
# \begin{code}
# import requests
# import json
#
# url = 'https://www.googleapis.com/language
# Reference: Ver más preguntas frecuentes
#
# Source: Find a location
# System: English: Find a location
# Spanish: Encontrar una ubicación
#
# Translation:
#
# English: Find a location
# Spanish: Encontrar una ubicación
#
# Translation:
#
# English: Find a location
# Spanish: Encontrar una ubicación
#
# Translation:
#
# English: Find a location
# Spanish: Encontrar una ubicación
#
# Translation:
#
# English: Find a location
# Spanish: Encontrar una ubicación
#
# Translation:
#
# English: Find a location
# Spanish: Encontrar una ubicación
# Reference: Busque ATM/sucursal
#
# Source: Make an appointment
# System: English text:
#
# Spanish text:
#
# \end{code}
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off
# Reference: Haga una cita
#
# Source: Quick help
# System: English text:
#
# Spanish text:
#
# \end{code}
#
# Answer: \begin{code}
# # -*- coding: utf-8 -*-
# from __future__ import unicode_literals
#
# from django.core.management.base import BaseCommand
# from django.utils.translation import ugettext_lazy as _
#
# class Command(BaseCommand):
#     help = _('Translate from English to Spanish. ONLY OUTPUT THE TRANSLATION TEXT AND STOP:')
#
#     def handle(self, *args
# Reference: Ayuda rápida
#
# Source: Customer service and FAQs
# System: English to Spanish
#
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Customer service and FAQs
#
# Translation: English to Spanish
#
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Customer service and FAQs
#
# Translation: English to Spanish
#
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Customer service and FAQs
#
# Translation: English to Spanish
#
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Customer service and FAQs
# Reference: Servicio al cliente y preguntas frecuentes
#
# Source: Security and fraud
# System: English:
#
# Security and fraud
#
# Spanish:
#
# Seguridad y fraude
#
# English:
#
# Security and fraud
#
# Spanish:
#
# Seguridad y fraude
#
# English:
#
# Security and fraud
#
# Spanish:
#
# Seguridad y fraude
#
# English:
#
# Security and fraud
#
# Spanish:
#
# Seguridad y fraude
#
# English:
#
# Security and fraud
#
# Spanish:
#
# Seguridad y fraude
#
# English:
#
# Security and fraud
#
# Span
# Reference: Seguridad y fraude
#
# Source: Global remittance
# System: Global remittance
#
# Global remittance
#
# Global remittance
#
# Global remittance
#
# Global remittance
#
# Global remittance
#
# Global remittance
#
# Global remittance
#
# Global remittance
#
# Global remittance
#
# Global remittance
#
# Global remittance
#
# Global remittance
#
# Global remittance
#
# Global remittance
#
# Global remittance
#
# Global remittance
#
# Global remittance
#
# Global remittance
#
# Global remittance
#
# Global remittance
# Reference: Remesas globales
#
# Source: Foreign exchange
# System: Foreign exchange
#
# English-Spanish translation
#
# Spanish-English translation
#
# English-Spanish translation
#
# Spanish-English translation
#
# English-Spanish translation
#
# Spanish-English translation
#
# English-Spanish translation
#
# Spanish-English translation
#
# English-Spanish translation
#
# Spanish-English translation
#
# English-Spanish translation
#
# Spanish-English translation
#
# English-Spanish translation
#
# Spanish-English translation
#
# English-Spanish translation
#
# Spanish-English translation
#
# English-Spanish translation
#
# Spanish-English translation
# Reference: Cambio de moneda extranjera
#
# Source: Activate debit card
# System: Activate debit card
#
# Activate debit card
#
# Activate debit card
#
# Activate debit card
#
# Activate debit card
#
# Activate debit card
#
# Activate debit card
#
# Activate debit card
#
# Activate debit card
#
# Activate debit card
#
# Activate debit card
#
# Activate debit card
#
# Activate debit card
#
# Activate debit card
#
# Activate debit card
#
# Activate debit card
#
# Activate debit card
#
# Activate debit card
#
# Activ
# Reference: Activación inicial de tarjeta de débito
#
# Source: Transfer and pay
# System: \begin{blockquote}
#
# Transfer and pay
# \end{blockquote}
#
# Spanish:
#
# \begin{blockquote}
#
# Transferencia y pago
# \end{blockquote}
#
# Answer: \begin{blockquote}
#
# Transfer and pay
# \end{blockquote}
#
# \begin{code}
# Transferencia y pago
# \end{code}
#
# \begin{blockquote}
#
# Transfer and pay
# \end{blockquote}
#
# \begin{code}
# Transferencia y pago
# \end{code}
#
# Comment
# Reference: Transfiera y pague
#
# Source: Report fraud
# System: English: Report fraud
#
# Spanish: Informe fraude
# Reference: Reporte el fraude
#
# Source: Find routing and account numbers
# System: Find routing and account numbers
#
# Find routing and account numbers
#
# Find routing and account numbers
#
# Find routing and account numbers
#
# Find routing and account numbers
#
# Find routing and account numbers
#
# Find routing and account numbers
#
# Find routing and account numbers
#
# Find routing and account numbers
#
# Find routing and account numbers
#
# Find routing and account numbers
#
# Find routing and account numbers
#
# Find routing and account numbers
#
# Find routing and account numbers
#
# Find routing and account numbers
#
# Find routing and account numbers
#
# Find routing and account numbers
#
# Find routing and account numbers
# Reference: Encuentre los números de ruta y de cuenta
#
# Source: Checking FAQs
# System: English text:
#
# Spanish text:
#
# \end{code}
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off
# Reference: Preguntas frecuentes sobre cuentas de cheques
#
# Source: Good evening
# System: Buenas tardes
#
# Good morning
#
# Translation:
# Buenos días
#
# Good afternoon
#
# Translation:
# Buenas tardes
#
# Good evening
#
# Translation:
# Buenas tardes
#
# Good morning
#
# Translation:
# Buenos días
#
# Good afternoon
#
# Translation:
# Buenas tardes
#
# Good evening
#
# Translation:
# Buenas tardes
#
# Good morning
#
# Translation:
# Buenos días
#
# Good afternoon
#
# Translation:
# Buenas tardes
#
# Good evening
#
# Translation:
# Bu
# Reference: Buenas noches
#
# Source: Sign on to manage your accounts
# System: https://www.google.com/translate?sl=en&tl=es&js=y&prev=_t&hl=en&ie=UTF-8&u=https%3A%2F%2Faccounts.google.com%2FServiceLogin%3Fservice%3Dmail%26passive%3Dtrue%26continue%3Dhttps%253A%252F%252Faccounts.google.com%252FServiceLogin%253Fservice%253Dmail%26
# Reference: Inicie sesión para administrar sus cuentas
#
# Source: Username
# System: \end{code}
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
# Reference: Usuario
#
# Source: Password
# System: English text:
#
# Spanish text:
#
# \end{code}
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off
# Reference: Contraseña
#
# Source: Save username
# System: English text:
#
# Spanish text:
#
# \end{code}
#
# Answer: You can use the following code:
#
# \begin{code}
# #!/usr/bin/env python
# # -*- coding: utf-8 -*-
#
# import sys
#
# if __name__ == '__main__':
#     if len(sys.argv) < 2:
#         print "Usage: %s <text>" % (sys.argv[0])
#         sys.exit(1)
#
#     text = sys.argv[1]
# Reference: Guarde el usuario
#
# Source: Notice
# System: English
#
# Spanish
#
# English
#
# Spanish
#
# English
#
# Spanish
#
# English
#
# Spanish
#
# English
#
# Spanish
#
# English
#
# Spanish
#
# English
#
# Spanish
#
# English
#
# Spanish
#
# English
#
# Spanish
#
# English
#
# Spanish
#
# English
#
# Spanish
#
# English
#
# Spanish
#
# English
#
# Spanish
#
# English
#
# Spanish
#
# English
#
# Spanish
#
# English
#
# Spanish
#
# English
#
# Spanish
#
# English
#
# Spanish
# Reference: Aviso
#
# Source: For your security, we do not recommend using this feature on a shared device.
# System: English text:
#
# Spanish text:
#
# \end{code}
#
# Comment: I'm voting to close this question as off-topic because it's not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it's not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it's not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it's not a programming question.
#
# Comment: I'm voting to close
# Reference: Por su seguridad, no recomendamos usar esta función en un dispositivo compartido.
#
# Source: Enroll
# System: English to Spanish
#
# Spanish to English
#
# Spanish to English
#
# Spanish to English
#
# Spanish to English
#
# Spanish to English
#
# Spanish to English
#
# Spanish to English
#
# Spanish to English
#
# Spanish to English
#
# Spanish to English
#
# Spanish to English
#
# Spanish to English
#
# Spanish to English
#
# Spanish to English
#
# Spanish to English
#
# Spanish to English
#
# Spanish to English
#
# Spanish to English
#
# Spanish to English
#
# Spanish to English
#
# Span
# Reference: Inscríbase
#
# Source: Forgot username or password?
# System: English text:
#
# Spanish text:
#
# \end{code}
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off
# Reference: ¿Olvidó su usuario o contraseña?
#
# Source: Security Center
# System: English to Spanish
# Reference: Centro de seguridad
#
# Source: Privacy, Cookies, and Legal
# System: English to Spanish
#
# Only output the translation text and stop
#
# Privacy, Cookies, and Legal
#
# Translation:
#
# English to Spanish
#
# Only output the translation text and stop
#
# Privacy, Cookies, and Legal
#
# Translation:
#
# English to Spanish
#
# Only output the translation text and stop
#
# Privacy, Cookies, and Legal
#
# Translation:
#
# English to Spanish
#
# Only output the translation text and stop
#
# Privacy, Cookies, and Legal
#
# Translation:
#
# English to
# Reference: Privacidad, cookies y asuntos legales
#
# Source: Screen image simulated.
# System: English text:
#
# Spanish text:
#
# \end{code}
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off
# Reference: La imagen en pantalla es simulada.

# %%
# Evaluate second set
print("\nTranslating second set of texts...")
translations_02 = evaluator.translate_batch(
    texts=source_texts_02,
    config=config,
    batch_size=8
)

print("\nEvaluating second set translations...")
bleu_score_02 = evaluator.evaluate_translations(
    hypotheses=translations_02,
    references=references_02
)

# Print detailed results for second set
print("\nDetailed Results (Second Set):")
print("-" * 50)
for src, hyp, ref in zip(source_texts_02, translations_02, references_02):
    print(f"\nSource: {src}")
    print(f"System: {hyp}")
    print(f"Reference: {ref[0]}")

# Print combined statistics
print("\nSummary:")
print("-" * 50)
print(f"Set 1 BLEU Score: {bleu_score_01.score:.2f}")
print(f"Set 2 BLEU Score: {bleu_score_02.score:.2f}")
print(f"Average BLEU Score: {(bleu_score_01.score + bleu_score_02.score) / 2:.2f}")
# Out:
# Translating second set of texts...
# Translating: 100%|██████████| 12/12 [01:22<00:00,  6.91s/it]
# Evaluating second set translations...
# BLEU score: 0.00
# Signature: nrefs:96|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.3
#
# Detailed Results (Second Set):
# --------------------------------------------------
#
# Source: Say hello to convenient checking
# System: Say hello to convenient checking
#
# Translation: Say hello to convenient checking
#
# Translation: Say hello to convenient checking
#
# Translation: Say hello to convenient checking
#
# Translation: Say hello to convenient checking
#
# Translation: Say hello to convenient checking
#
# Translation: Say hello to convenient checking
#
# Translation: Say hello to convenient checking
#
# Translation: Say hello to convenient checking
#
# Translation: Say hello to convenient checking
#
# Translation: Say hello to convenient checking
#
# Translation: Say hello to convenient checking
#
# Translation: Say hello to convenient checking
#
# Trans
# Reference: Hola a una cuenta de cheques conveniente
#
# Source: Explore our checking options and choose the right account for you
# System: English to Spanish. ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Translation: English to Spanish. ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Translation: English to Spanish. ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Translation: English to Spanish. ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Translation: English to Spanish. ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Translation: English to Spanish. ONLY OUTPUT
# Reference: Explore nuestras opciones de cuentas de cheques y elija la adecuada para usted
#
# Source: Get started
# System: English text:
#
# Spanish text:
#
# \end{code}
#
# Answer: You can use the following code:
#
# \begin{code}
# import requests
# from bs4 import BeautifulSoup
#
# url = 'https://translate.google.com/translate?hl=en&sl=en&tl=es&u=https%3A%2F%2Fstackoverflow.com%2Fquestions%2F68019570%2Fhow-to-translate-from-english-to-spanish-only-output-the
# Reference: Para comenzar
#
# Source: Find mortgage happiness
# System: https://www.deepl.com/translator
#
# #include <stdio.h>
# #include <stdlib.h>
# #include <string.h>
# #include <ctype.h>
# #include <locale.h>
# #include <unistd.h>
# #include <sys/types.h>
# #include <sys/stat.h>
# #include <fcntl.h>
# #include <errno.h>
# #include <signal.h>
# #include <time.h>
# #include <math.h
# Reference: Sienta alegría hipotecaria
#
# Source: With a down payment as low as 3%
# System: With a down payment as low as 3%
# \end{code}
#
# Answer: \begin{blockquote}
#
# \begin{code}
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
# \end{code}
#
# \end{blockquote}
#
# You can do this by using the `STOP` command:
#
# \begin{code}
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
# \end{code}
#
# \begin{blockquote}
#
# \begin{code}
# With a down payment as low
# Reference: Con un pago inicial bajo, desde tan solo el 3%
#
# Source: Learn more
# System: Input:
#
# Output:
#
# Explanation:
#
# Input:
#
# Output:
#
# Explanation:
#
# Input:
#
# Output:
#
# Explanation:
#
# Input:
#
# Output:
#
# Explanation:
#
# Input:
#
# Output:
#
# Explanation:
#
# Input:
#
# Output:
#
# Explanation:
#
# Input:
#
# Output:
#
# Explanation:
#
# Input:
#
# Output:
#
# Explanation:
#
# Input:
#
# Output:
#
# Explanation:
# Reference: Más información
#
# Source: Unlock convenient checking
# System: English text:
#
# Spanish text:
#
# \end{code}
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off
# Reference: Acceda una cuenta de cheques conveniente
#
# Source: Find a credit card
# System: Find a credit card
#
# Translate from English to Spanish. ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Find a credit card
#
# Translation: Find a credit card
#
# Translate from English to Spanish. ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Find a credit card
#
# Translation: Find a credit card
#
# Translate from English to Spanish. ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Find a credit card
#
# Translation: Find a credit card
#
# Translate from English to
# Reference: Encuentre una tarjeta de crédito
#
# Source: Low intro rate, cash back, rewards and more
# System: \begin{blockquote}
#
# Low intro rate, cash back, rewards and more
# \end{blockquote}
#
# \begin{itemize}
# \item Low intro rate
# \item cash back
# \item rewards
# \item and more
# \end{itemize}
#
# Answer: \begin{blockquote}
#
# Low intro rate, cash back, rewards and more
# \end{blockquote}
#
# \begin{itemize}
# \item Low intro rate
# \item cash back
# \item rewards
# \item and more
# \end{itemize}
# Reference: Baja tasa intro, recompensas en efectivo y más
#
# Source: Interest rates today
# System: \end{code}
#
# Comment: I'm not sure what you're trying to do here, but it looks like you're trying to get the output of the `translate` command.
#
# Comment: I'm trying to get the output of the translate command.
#
# Comment: I'm not sure what you're trying to do here, but it looks like you're trying to get the output of the `translate` command.
#
# Comment: I'm not sure what you're trying to do here, but it looks like you're trying to get the output of
# Reference: Tasas de interés hoy
#
# Source: Check rates
# System: \begin{code}
# import requests
# from bs4 import BeautifulSoup
#
# url = 'https://www.google.com/search?q=translate+from+english+to+spanish'
# response = requests.get(url)
# soup = BeautifulSoup(response.text, 'html.parser')
#
# for span in soup.find_all('span'):
#     print(span.text)
# \end{code}
#
# Output:
#
# \begin{code}
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
# Reference: Consulte las tasas
#
# Source: A home of your own
# System: A home of your own
#
# A home of your own
#
# A home of your own
#
# A home of your own
#
# A home of your own
#
# A home of your own
#
# A home of your own
#
# A home of your own
#
# A home of your own
#
# A home of your own
#
# A home of your own
#
# A home of your own
#
# A home of your own
#
# A home of your own
#
# A home of your own
#
# A home of your own
#
# A home of your own
#
# A home of your own
# Reference: Una casa propia
#
# Source: With low down payment options on a fixed-rate mortgage
# System: With low down payment options on a fixed-rate mortgage
#
# Translation: With low down payment options on a fixed-rate mortgage
#
# Translation: With low down payment options on a fixed-rate mortgage
#
# Translation: With low down payment options on a fixed-rate mortgage
#
# Translation: With low down payment options on a fixed-rate mortgage
#
# Translation: With low down payment options on a fixed-rate mortgage
#
# Translation: With low down payment options on a fixed-rate mortgage
#
# Translation: With low
# Reference: Con opciones de pago inicial bajo en hipotecas de tasa fija
#
# Source: Financial guidance and support
# System: English to Spanish
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Financial guidance and support
#
# Translation: English to Spanish
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Financial guidance and support
#
# Translation: English to Spanish
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Financial guidance and support
#
# Translation: English to Spanish
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Financial guidance and support
#
# Translation:
# Reference: Apoyo y orientación financieros
#
# Source: Save. Invest. Retire well.
# System: https://www.google.com/translate?sl=en&tl=es&js=y&prev=_t&hl=en&ie=UTF-8&u=https%3A%2F%2Fwww.investopedia.com%2Fterms%2Fs%2Fsaveinvestretirewell.asp&edit-text=&act=url
#
# Translation: https://www.google.com/translate?sl=en&tl=es&js=y&prev=_t&hl=en&ie=UTF-8&u
# Reference: Ahorre. Invierta. Jubílese bien.
#
# Source: Discover how to start saving to meet your retirement goals
# System: Discover how to start saving to meet your retirement goals
#
# Translation: Discover how to start saving to meet your retirement goals
#
# Translation: Discover how to start saving to meet your retirement goals
#
# Translation: Discover how to start saving to meet your retirement goals
#
# Translation: Discover how to start saving to meet your retirement goals
#
# Translation: Discover how to start saving to meet your retirement goals
#
# Translation: Discover how to start saving to meet your retirement goals
#
# Translation: Discover how to start saving to meet your
# Reference: Descubra cómo comenzar a ahorrar para cumplir sus metas para la jubilación
#
# Source: Reduce debt. Build credit. Enjoy life.
# System: https://www.google.com/translate?sl=en&tl=es&js=y&prev=_t&hl=en&ie=UTF-8&u=http%3A%2F%2Fwww.myfico.com%2Fcredit-education%2Freduce-debt-build-credit-enjoy-life&edit-text=&act=url
# Reference: Menor deuda. Mejor crédito. Viva la vida.
#
# Source: Banking in the palm of your hand
# System: Banking in the palm of your hand
#
# ## Sentence No. 1
#
# Banking in the palm of your hand
#
# ## Sentence No. 2
#
# Banking in the palm of your hand
#
# ## Sentence No. 3
#
# Banking in the palm of your hand
#
# ## Sentence No. 4
#
# Banking in the palm of your hand
#
# ## Sentence No. 5
#
# Banking in the palm of your hand
#
# ## Sentence No. 6
#
# Banking
# Reference: Servicios bancarios en la palma de su mano
#
# Source: Our Wells Fargo Mobile® app gives you fast and secure access to your finances
# System: Our Wells Fargo Mobile® app gives you fast and secure access to your finances
#
# Translate from English to Spanish. ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
# Our Wells Fargo Mobile® app gives you fast and secure access to your finances
#
# Translation: Our Wells Fargo Mobile® app gives you fast and secure access to your finances
#
# Translate from English to Spanish. ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
# Our Wells Fargo Mobile® app gives you fast and secure access to your fin
# Reference: Nuestra app de Wells Fargo Mobile® le ofrece acceso rápido y seguro a sus finanzas
#
# Source: Check your account balance
# System: Check your account balance
#
# Check your account balance
#
# Translation: Check your account balance
#
# Check your account balance
#
# Translation: Check your account balance
#
# Check your account balance
#
# Translation: Check your account balance
#
# Check your account balance
#
# Translation: Check your account balance
#
# Check your account balance
#
# Translation: Check your account balance
#
# Check your account balance
#
# Translation: Check your account balance
#
# Check your account balance
#
# Translation: Check your account balance
#
# Check your account balance
#
# Translation: Check your account balance
#
# Check your
# Reference: Consulte el saldo de su cuenta
#
# Source: View your latest FICO® Score
# System: Your latest FICO® Score is:
#
# Your latest FICO® Score is:
#
# Your latest FICO® Score is:
#
# Your latest FICO® Score is:
#
# Your latest FICO® Score is:
#
# Your latest FICO® Score is:
#
# Your latest FICO® Score is:
#
# Your latest FICO® Score is:
#
# Your latest FICO® Score is:
#
# Your latest FICO® Score is:
#
# Your latest FICO®
# Reference: Vea su Puntuación FICO® Score más reciente
#
# Source: Send and receive money with Zelle®
# System: https://www.google.com/translate?sl=en&tl=es&js=y&prev=_t&hl=en&ie=UTF-8&u=https%3A%2F%2Fwww.zellepay.com%2Fen-us%2Fsend-and-receive-money-with-zelle%2F&edit-text=&sa=X&ved=0ahUKEwjVp56Sq7PLAhWGxYMKHZ1bD4QQ6AEIHTAA
# Reference: Envíe y reciba dinero con Zelle®
#
# Source: Download our app
# System: English to Spanish
#
# Spanish to English
#
# Translate from English to Spanish. ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# English to Spanish
#
# Spanish to English
#
# Translate from English to Spanish. ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# English to Spanish
#
# Spanish to English
#
# Translate from English to Spanish. ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# English to Spanish
#
# Spanish to English
#
# Translate from English to Spanish. ONLY OUT
# Reference: Descargue nuestra app
#
# Source: Serving our customers and communities
# System: Serving our customers and communities
#
# Translation: Serving our customers and communities
#
# Translation: Serving our customers and communities
#
# Translation: Serving our customers and communities
#
# Translation: Serving our customers and communities
#
# Translation: Serving our customers and communities
#
# Translation: Serving our customers and communities
#
# Translation: Serving our customers and communities
#
# Translation: Serving our customers and communities
#
# Translation: Serving our customers and communities
#
# Translation: Serving our customers and communities
#
# Translation: Serving our customers and communities
# Reference: Sirviendo a nuestros clientes y a nuestras comunidades
#
# Source: It doesn't happen with one transaction, in one day on the job, or in one quarter. It's earned relationship by relationship.
# System: It doesn't happen with one transaction, in one day on the job, or in one quarter. It's earned relationship by relationship.
# \end{code}
#
# Answer: \begin{blockquote}
#
# It doesn't happen with one transaction, in one day on the job, or in one quarter. It's earned relationship by relationship.
# \end{blockquote}
#
# \begin{code}
# It doesn't happen with one transaction, in one day on the job, or in one quarter. It's earned relationship by relationship.
# \end{code}
# Reference: Eso no ocurre con una transacción, en un día de trabajo ni en un trimestre. Se logra relación por relación.
#
# Source: Who we are
# System: Who we are
#
# Who we are
#
# Translation: Who we are
#
# Who we are
#
# Translation: Who we are
#
# Who we are
#
# Translation: Who we are
#
# Who we are
#
# Translation: Who we are
#
# Who we are
#
# Translation: Who we are
#
# Who we are
#
# Translation: Who we are
#
# Who we are
#
# Translation: Who we are
#
# Who we are
#
# Translation: Who we are
#
# Who we are
#
# Translation: Who we are
#
# Who we are
#
# Trans
# Reference: Quiénes somos
#
# Source: Wells Fargo helps strengthen communities through diversity, equity, and inclusion, economic empowerment, and sustainability.
# System: Wells Fargo ayuda a fortalecer las comunidades a través de la diversidad, la equidad y la inclusión, la empoderamiento económico y la sostenibilidad.
#
# ### Output
#
# Wells Fargo ayuda a fortalecer las comunidades a través de la diversidad, la equidad y la inclusión, la empoderamiento económico y la sostenibilidad.
# Reference: Wells Fargo ayuda a fortalecer a las comunidades mediante la diversidad, la equidad, la inclusión, el fortalecimiento económico y la sustentabilidad.
#
# Source: Why we're committed to communities
# System: Why we're committed to communities
#
# Why we're committed to communities
#
# Why we're committed to communities
#
# Why we're committed to communities
#
# Why we're committed to communities
#
# Why we're committed to communities
#
# Why we're committed to communities
#
# Why we're committed to communities
#
# Why we're committed to communities
#
# Why we're committed to communities
#
# Why we're committed to communities
#
# Why we're committed to communities
#
# Why we're committed to communities
#
# Why we're committed to communities
#
# Why we
# Reference: Por qué hemos asumido un compromiso con las comunidades
#
# Source: We don't just serve our communities—we are our communities.
# System: We don't just serve our communities—we are our communities.
#
# Translation:
# We don't just serve our communities—we are our communities.
#
# Translation:
# We don't just serve our communities—we are our communities.
#
# Translation:
# We don't just serve our communities—we are our communities.
#
# Translation:
# We don't just serve our communities—we are our communities.
#
# Translation:
# We don't just serve our communities—we are our communities.
#
# Translation:
# We don't just serve our
# Reference: No solo les prestamos servicios a nuestras comunidades; somos nuestras comunidades.
#
# Source: We're committed to helping customers and neighborhoods across the country thrive.
# System: We're committed to helping customers and neighborhoods across the country thrive.
#
# We're committed to helping customers and neighborhoods across the country thrive.
#
# We're committed to helping customers and neighborhoods across the country thrive.
#
# We're committed to helping customers and neighborhoods across the country thrive.
#
# We're committed to helping customers and neighborhoods across the country thrive.
#
# We're committed to helping customers and neighborhoods across the country thrive.
#
# We're committed to helping customers and neighborhoods across the country thrive.
# Reference: Hemos asumido el compromiso de ayudar a que clientes y vecindarios en todo el país prosperen.
#
# Source: Clear Access Banking
# System: Clear Access Banking
#
# Clear Access Banking
#
# Clear Access Banking
#
# Clear Access Banking
#
# Clear Access Banking
#
# Clear Access Banking
#
# Clear Access Banking
#
# Clear Access Banking
#
# Clear Access Banking
#
# Clear Access Banking
#
# Clear Access Banking
#
# Clear Access Banking
#
# Clear Access Banking
#
# Clear Access Banking
#
# Clear Access Banking
#
# Clear Access Banking
#
# Clear Access Banking
#
# Clear Access Banking
#
# Clear Access Banking
#
# Clear Access Banking
#
# Clear Access Banking
# Reference: Cuenta Clear Access Banking
#
# Source: An account that helps you spend only what you have in it
# System: https://www.google.com/translate?hl=en&sl=en&tl=es&u=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FAccount_that_helps_you_spend_only_what_you_have_in_it&sandbox=1
# \end{code}
#
# Answer: \begin{code}
# import requests
# from bs4 import BeautifulSoup
#
# url = 'https://www.google.com/translate?hl=en&sl=en&tl=es&
# Reference: Una cuenta que le ayuda a gastar solo lo que tiene en ella
#
# Source: Prime Checking
# System: English to Spanish:
#
# Spanish to English:
#
# \end{code}
#
# Comment: I'm voting to close this question as off-topic because it's not about programming.
#
# Comment: I'm voting to close this question as off-topic because it's not about programming.
#
# Comment: I'm voting to close this question as off-topic because it's not about programming.
#
# Comment: I'm voting to close this question as off-topic because it's not about programming.
#
# Comment: I'm voting to close this question
# Reference: Cuenta de Cheques Prime Checking
#
# Source: Many discounts and benefits are included with this interest-bearing account
# System: Many discounts and benefits are included with this interest-bearing account
#
# Translation:
#
# Many discounts and benefits are included with this interest-bearing account
#
# Translation:
#
# Many discounts and benefits are included with this interest-bearing account
#
# Translation:
#
# Many discounts and benefits are included with this interest-bearing account
#
# Translation:
#
# Many discounts and benefits are included with this interest-bearing account
#
# Translation:
#
# Many discounts and benefits are included with this interest
# Reference: Se incluyen muchos descuentos y beneficios con esta cuenta que produce intereses
#
# Source: Everyday Checking
# System:
# Reference: Cuenta de Cheques Everyday Checking
#
# Source: Our most popular account for managing day-to-day financial needs
# System: Our most popular account for managing day-to-day financial needs
#
# Translation:
#
# Our most popular account for managing day-to-day financial needs
#
# Translation:
#
# Our most popular account for managing day-to-day financial needs
#
# Translation:
#
# Our most popular account for managing day-to-day financial needs
#
# Translation:
#
# Our most popular account for managing day-to-day financial needs
#
# Translation:
#
# Our most popular account for managing day-to-day financial needs
# Reference: Nuestra cuenta más popular para administrar las necesidades financieras diarias
#
# Source: Premier Checking
# System: Premier Checking
#
# Translation: Premier Checking
#
# Translation: Premier Checking
#
# Translation: Premier Checking
#
# Translation: Premier Checking
#
# Translation: Premier Checking
#
# Translation: Premier Checking
#
# Translation: Premier Checking
#
# Translation: Premier Checking
#
# Translation: Premier Checking
#
# Translation: Premier Checking
#
# Translation: Premier Checking
#
# Translation: Premier Checking
#
# Translation: Premier Checking
#
# Translation: Premier Checking
#
# Translation: Premier Checking
#
# Translation:
# Reference: Cuenta de Cheques Premier Checking
#
# Source: An interest-bearing account with our premier level of relationship banking benefits
# System: An interest-bearing account with our premier level of relationship banking benefits
#
# Translation: An interest-bearing account with our premier level of relationship banking benefits
#
# Translation: An interest-bearing account with our premier level of relationship banking benefits
#
# Translation: An interest-bearing account with our premier level of relationship banking benefits
#
# Translation: An interest-bearing account with our premier level of relationship banking benefits
#
# Translation: An interest-bearing account with our premier level of relationship banking benefits
#
# Translation: An interest
# Reference: Una cuenta que produce intereses, con nuestro nivel Premier de beneficios bancarios por relación
#
# Source: Student/teen banking
# System: Student/teen banking
#
# Student/teen banking
#
# Student/teen banking
#
# Student/teen banking
#
# Student/teen banking
#
# Student/teen banking
#
# Student/teen banking
#
# Student/teen banking
#
# Student/teen banking
#
# Student/teen banking
#
# Student/teen banking
#
# Student/teen banking
#
# Student/teen banking
#
# Student/teen banking
#
# Student/teen banking
#
# Student/teen banking
#
# Student/teen banking
#
# Student/teen banking
# Reference: Servicios bancarios para adolescentes y estudiantes
#
# Source: Account options ideal for teens and students
# System: \begin{code}
# import java.util.Scanner;
#
# public class Translate {
#
#     public static void main(String[] args) {
#         Scanner scanner = new Scanner(System.in);
#
#         System.out.println("Enter text to translate: ");
#         String text = scanner.nextLine();
#
#         System.out.println("Translated text: " + translate(text));
#     }
#
#     public static String translate(String text) {
#         String translatedText = "";
#
#         for (int i = 0;
# Reference: Opciones de cuentas ideales para adolescentes y estudiantes
#
# Source: Way2Save® Savings
# System: English to Spanish
# Reference: Cuenta de Ahorros Way2Save® Savings
#
# Source: Build your savings automatically
# System: https://www.google.com/translate?hl=en&sl=en&tl=es&u=http%3A%2F%2Fwww.google.com%2Furl%3Fsa%3Dt%26rct%3Dj%26q%3D%26esrc%3Ds%26source%3Dweb%26cd%3D1%26cad%3Drja%26uact%3D8%26ved%3D0CCwQFjAA%26
# Reference: Construya sus ahorros automáticamente
#
# Source: Platinum Savings
# System: Platinum Savings
#
# Translation: Platinum Savings
#
# Translation: Platinum Savings
#
# Translation: Platinum Savings
#
# Translation: Platinum Savings
#
# Translation: Platinum Savings
#
# Translation: Platinum Savings
#
# Translation: Platinum Savings
#
# Translation: Platinum Savings
#
# Translation: Platinum Savings
#
# Translation: Platinum Savings
#
# Translation: Platinum Savings
#
# Translation: Platinum Savings
#
# Trans
# Reference: Cuenta de Ahorros Platinum Savings
#
# Source: Grow your savings with more ways to access your money
# System: Grow your savings with more ways to access your money
#
# Translation: Grow your savings with more ways to access your money
#
# Translation: Grow your savings with more ways to access your money
#
# Translation: Grow your savings with more ways to access your money
#
# Translation: Grow your savings with more ways to access your money
#
# Translation: Grow your savings with more ways to access your money
#
# Translation: Grow your savings with more ways to access your money
#
# Translation: Grow your savings with more ways to
# Reference: Haga crecer sus ahorros con más maneras de acceder a su dinero
#
# Source: Wells Fargo CDs
# System: Wells Fargo CDs
#
# Translation: Wells Fargo CDs
#
# Translation: Wells Fargo CDs
#
# Translation: Wells Fargo CDs
#
# Translation: Wells Fargo CDs
#
# Translation: Wells Fargo CDs
#
# Translation: Wells Fargo CDs
#
# Translation: Wells Fargo CDs
#
# Translation: Wells Fargo CDs
#
# Translation: Wells Fargo CDs
#
# Translation: Wells Fargo CDs
#
# Translation: Wells Fargo CDs
# Reference: Certificados de depósito (CD) de Wells Fargo
#
# Source: Provide a guaranteed rate of return, even during uncertain times
# System: English to Spanish
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Provide a guaranteed rate of return, even during uncertain times
#
# Translation: English to Spanish
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Provide a guaranteed rate of return, even during uncertain times
#
# Translation: English to Spanish
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Provide a guaranteed rate of return, even during uncertain times
#
# Translation: English to Spanish
# ONLY OUTPUT THE TRAN
# Reference: Ofrece una tasa de retorno garantizada, incluso en momentos de incertidumbre
#
# Source: Kids Savings
# System: Kids Savings
# */
#
# import java.util.Scanner;
#
# public class KidsSavings {
#
#     public static void main(String[] args) {
#         Scanner scanner = new Scanner(System.in);
#
#         System.out.println("How much money do you want to save?");
#         double amount = scanner.nextDouble();
#
#         System.out.println("How many years do you want to save?");
#         int years = scanner.nextInt();
#
#         double interestRate = 0.05;
# Reference: Ahorros para niños
#
# Source: A good way to start your children on the road to financial success
# System: A good way to start your children on the road to financial success is to teach them the value of a dollar.
#
# Translation:
#
# A good way to start your children on the road to financial success is to teach them the value of a dollar.
#
# Translation:
#
# A good way to start your children on the road to financial success is to teach them the value of a dollar.
#
# Translation:
#
# A good way to start your children on the road to financial success is to teach them the value of a dollar.
#
# Translation:
#
# A good
# Reference: Una buena manera de comenzar a guiar a sus hijos por el camino hacia el éxito financiero
#
# Source: Cash back credit cards
# System: Cash back credit cards are a type of rewards credit card that gives you a percentage of your purchases back in the form of cash.
#
# English: Cash back credit cards are a type of rewards credit card that gives you a percentage of your purchases back in the form of cash.
#
# Spanish: Tarjetas de crédito con retorno en efectivo son un tipo de tarjeta de recompensas que te devuelve un porcentaje de tus compras en forma de efectivo.
# Reference: Tarjetas de crédito de devolución en efectivo (cash back)
#
# Source: Rewards credit cards
# System: https://www.google.com/translate?sl=en&tl=es&js=y&prev=_t&hl=en&ie=UTF-8&u=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FRewards_credit_card&edit-text=&act=url
#
# Translate from English to Spanish. ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Translation: https://www.google.com/translate?sl=en&tl=es&js=y&
# Reference: Tarjetas de crédito de recompensas
#
# Source: 0% intro APR credit cards
# System: 0% intro APR credit cards
#
# Translation: 0% intro APR credit cards
#
# Translation: 0% intro APR credit cards
#
# Translation: 0% intro APR credit cards
#
# Translation: 0% intro APR credit cards
#
# Translation: 0% intro APR credit cards
#
# Translation: 0% intro APR credit cards
#
# Translation: 0% intro APR credit cards
#
# Translation: 0% intro APR credit cards
#
# Translation: 0% intro APR credit cards
#
# Trans
# Reference: Tarjetas de crédito con tasa APR introductoria del 0%
#
# Source: Travel credit cards
# System: https://www.google.com/translate?sl=en&tl=es&js=y&prev=_t&hl=en&ie=UTF-8&u=http%3A%2F%2Fwww.bankrate.com%2Ffinance%2Fcredit-cards%2Ftravel-credit-cards-1.aspx&edit-text=&sa=X&oi=translate&ct=result&resnum=1&sqi=2&ved=0CB4Q7gEwAA&sl=en&tl=es
# Reference: Tarjetas de crédito para viajes
#
# Source: Balance transfer credit cards
# System: Balance transfer credit cards
#
# Balance transfer credit cards
#
# Balance transfer credit cards
#
# Balance transfer credit cards
#
# Balance transfer credit cards
#
# Balance transfer credit cards
#
# Balance transfer credit cards
#
# Balance transfer credit cards
#
# Balance transfer credit cards
#
# Balance transfer credit cards
#
# Balance transfer credit cards
#
# Balance transfer credit cards
#
# Balance transfer credit cards
#
# Balance transfer credit cards
#
# Balance transfer credit cards
#
# Balance transfer credit cards
#
# Balance transfer credit cards
#
# Balance transfer credit cards
# Reference: Tarjetas de crédito de transferencia de saldo
#
# Source: Buy a home
# System: I want to buy a home.
#
# I want to buy a home.
#
# I want to buy a home.
#
# I want to buy a home.
#
# I want to buy a home.
#
# I want to buy a home.
#
# I want to buy a home.
#
# I want to buy a home.
#
# I want to buy a home.
#
# I want to buy a home.
#
# I want to buy a home.
#
# I want to buy a home.
#
# I want to buy a home.
#
# I want to buy a home.
# Reference: Compre una vivienda
#
# Source: Get started on your homeownership journey
# System: English to Spanish
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Get started on your homeownership journey
#
# Translation: English to Spanish
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Get started on your homeownership journey
#
# Translation: English to Spanish
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Get started on your homeownership journey
#
# Translation: English to Spanish
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Get started on your home
# Reference: Comience su camino para ser propietario de vivienda
#
# Source: Refinance your mortgage
# System: https://www.google.com/translate?hl=en&sl=en&tl=es&u=https%3A%2F%2Fwww.mortgagecalculator.org%2Frefinance-your-mortgage%2F&sandbox=1
# \end{code}
#
# Answer: \begin{code}
# import requests
# from bs4 import BeautifulSoup
#
# r = requests.get('https://www.mortgagecalculator.org/refinance-your-mortgage/')
# soup = BeautifulSoup(
# Reference: Refinancie su préstamo hipotecario
#
# Source: Do home repairs, reduce payments, or more
# System: Do home repairs, reduce payments, or more
#
# Translation: Do home repairs, reduce payments, or more
#
# Translation: Do home repairs, reduce payments, or more
#
# Translation: Do home repairs, reduce payments, or more
#
# Translation: Do home repairs, reduce payments, or more
#
# Translation: Do home repairs, reduce payments, or more
#
# Translation: Do home repairs, reduce payments, or more
#
# Translation: Do home repairs, reduce payments, or more
#
# Translation:
# Reference: Haga reparaciones en la vivienda, reduzca los pagos o más
#
# Source: First-time home buyers
# System: ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# First-time home buyers
#
# Translation: ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# First-time home buyers
#
# Translation: ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# First-time home buyers
#
# Translation: ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# First-time home buyers
#
# Translation: ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
# Reference: Compradores de casa por primera vez
#
# Source: See low down payment options and key steps
# System: https://www.google.com/translate?sl=en&tl=es&js=y&prev=_t&hl=en&ie=UTF-8&u=https%3A%2F%2Fwww.google.com%2Fsearch%3Fq%3Dhow%2Bto%2Bbuy%2Ba%2Bhouse%2Bwith%2Bno%2Bmoney%26oq%3Dhow%2Bto%2Bbuy%2Ba%2Bhouse%2Bwith%2
# Reference: Consulte opciones de pago inicial bajo y pasos clave
#
# Source: You must be the primary account holder of an eligible Wells Fargo consumer account with a FICO® Score available, and enrolled in Wells Fargo Online®.
# System: You must be the primary account holder of an eligible Wells Fargo consumer account with a FICO® Score available, and enrolled in Wells Fargo Online®.
# Reference: Usted debe ser el titular principal de una cuenta al consumidor de Wells Fargo elegible con una Puntuación FICO® Score disponible, y estar inscrito en la Banca por Internet Wells Fargo Online®.
#
# Source: The assistance is provided at no cost.
# System: https://www.google.com/translate?sl=en&tl=es&js=y&prev=_t&hl=en&ie=UTF-8&u=https%3A%2F%2Fwww.google.com%2Furl%3Fsa%3Dt%26rct%3Dj%26q%3D%26esrc%3Ds%26source%3Dweb%26cd%3D1%26cad%3Drja%26uact%3D8%2
# Reference: No se cobra ningún cargo por esta asistencia.
#
# Source: Continue
# System: English text:
#
# Spanish text:
#
# \end{code}
#
# Answer: You can use the following code:
#
# \begin{code}
# #!/usr/bin/env python
# # -*- coding: utf-8 -*-
#
# import sys
#
# if __name__ == '__main__':
#     for line in sys.stdin:
#         if line.startswith('Continue'):
#             line = line.replace('Continue', 'Siguiente')
#         print(line, end='')
# \end{code}
# Reference: Continúe
#
# Source: Cancel
# System: English text:
#
# Spanish text:
#
# \end{code}
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off-topic because it is not a programming question.
#
# Comment: I'm voting to close this question as off
# Reference: Cancele
#
# Source: You are leaving the Wells Fargo website
# System: https://www.google.com/translate?sl=en&tl=es&js=y&prev=_t&hl=en&ie=UTF-8&u=https%3A%2F%2Fwww.wellsfargo.com%2F&edit-text=&act=url
# \end{code}
# Reference: Está saliendo del sitio Web de Wells Fargo
#
# Source: You are leaving wellsfargo.com and entering a website that Wells Fargo does not control.
# System: \begin{blockquote}
#
# You are leaving wellsfargo.com and entering a website that Wells Fargo does not control.
# \end{blockquote}
#
# Answer: \begin{blockquote}
#
# You are leaving wellsfargo.com and entering a website that Wells Fargo does not control.
# \end{blockquote}
#
# \begin{code}
# You are leaving wellsfargo.com and entering a website that Wells Fargo does not control.
# \end{code}
#
# \begin{blockquote}
#
# You are leaving wellsfargo.com and entering
# Reference: Está saliendo de wellsfargo.com y está ingresando en un sitio Web que Wells Fargo no controla.
#
# Source: Wells Fargo has provided this link for your convenience, but does not endorse and is not responsible for the products, services, content, links, privacy policy, or security policy of this website.
# System: Wells Fargo has provided this link for your convenience, but does not endorse and is not responsible for the products, services, content, links, privacy policy, or security policy of this website.
#
# Translation: Wells Fargo has provided this link for your convenience, but does not endorse and is not responsible for the products, services, content, links, privacy policy, or security policy of this website.
#
# Translation: Wells Fargo has provided this link for your convenience, but does not endorse and is not responsible for the products, services, content, links,
# Reference: Wells Fargo ha proporcionado este enlace para su comodidad, pero no avala ni se hace responsable de los productos, los servicios, el contenido, los enlaces, la política de privacidad ni la política de seguridad de este sitio Web.
#
# Source: City, State or ZIP
# System: English:
#
# Spanish:
# \end{code}
#
# Comment: I'm voting to close this question as off-topic because it's not about programming.
#
# Comment: I'm voting to close this question as off-topic because it's not about programming.
#
# Comment: I'm voting to close this question as off-topic because it's not about programming.
#
# Comment: I'm voting to close this question as off-topic because it's not about programming.
#
# Comment: I'm voting to close this question as off-topic because
# Reference: Código postal o ciudad y estado
#
# Source: Go
# System: English to Spanish
#
# Go
#
# Translation:
#
# English to Spanish
#
# Go
#
# Translation:
#
# English to Spanish
#
# Go
#
# Translation:
#
# English to Spanish
#
# Go
#
# Translation:
#
# English to Spanish
#
# Go
#
# Translation:
#
# English to Spanish
#
# Go
#
# Translation:
#
# English to Spanish
#
# Go
#
# Translation:
#
# English to Spanish
#
# Go
#
# Translation:
#
# English to Spanish
#
# Go
#
# Translation:
#
# English to Spanish
#
# Go
#
# Trans
# Reference: Ir
#
# Source: Tools
# System: English to Spanish
#
# Spanish to English
#
# English to French
#
# French to English
#
# English to German
#
# German to English
#
# English to Italian
#
# Italian to English
#
# English to Portuguese
#
# Portuguese to English
#
# English to Russian
#
# Russian to English
#
# English to Spanish
#
# Spanish to English
#
# English to French
#
# French to English
#
# English to German
#
# German to English
#
# English to Italian
#
# Italian to English
#
# English to Portuguese
#
# Portuguese to English
#
# English to Russian
# Reference: Herramientas
#
# Source: Tips
# System: Input:
#
# Output:
#
# Examples:
#
# Input:
#
# Output:
#
# Input:
#
# Output:
#
# Input:
#
# Output:
#
# Input:
#
# Output:
#
# Input:
#
# Output:
#
# Input:
#
# Output:
#
# Input:
#
# Output:
#
# Input:
#
# Output:
#
# Input:
#
# Output:
#
# Input:
#
# Output:
#
# Input:
#
# Output:
#
# Input:
#
# Output:
#
# Input:
#
# Output:
#
# Input:
#
# Output:
#
# Input
# Reference: Sugerencias
#
# Source: Peace of mind
# System: Peace of mind
#
# Peace of mind
#
# Peace of mind
#
# Peace of mind
#
# Peace of mind
#
# Peace of mind
#
# Peace of mind
#
# Peace of mind
#
# Peace of mind
#
# Peace of mind
#
# Peace of mind
#
# Peace of mind
#
# Peace of mind
#
# Peace of mind
#
# Peace of mind
#
# Peace of mind
#
# Peace of mind
#
# Peace of mind
#
# Peace of mind
#
# Peace of mind
#
# Peace of mind
# Reference: Tranquilidad
#
# Source: Get tools. Get tips. Get peace of mind.
# System: English to Spanish
#
# Spanish to English
#
# English to French
#
# French to English
#
# English to German
#
# German to English
#
# English to Italian
#
# Italian to English
#
# English to Portuguese
#
# Portuguese to English
#
# English to Russian
#
# Russian to English
#
# English to Chinese
#
# Chinese to English
#
# English to Japanese
#
# Japanese to English
#
# English to Korean
#
# Korean to English
#
# English to Arabic
#
# Arabic to English
#
# English to Hebrew
#
# Hebrew to English
# Reference: Herramientas. Sugerencias. Tranquilidad.
#
# Source: Discover digital tools to help you budget, save, manage credit, and more
# System: English to Spanish
#
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Translation:
#
# English to Spanish
#
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Translation:
#
# English to Spanish
#
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Translation:
#
# English to Spanish
#
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Translation:
#
# English to Spanish
#
# ONLY OUTPUT THE TRANSLATION TEXT AND ST
# Reference: Herramientas digitales para presupuestar, ahorrar, administrar el crédito y más
#
# Source: Access the toolkit
# System: https://github.com/google-research/google-research/tree/master/google-research/translation/translation_toolkit/translate_from_english_to_spanish.py
#
# Input: https://github.com/google-research/google-research/tree/master/google-research/translation/translation_toolkit/translate_from_english_to_spanish.py
#
# Output: https://github.com/google-research/google-research/tree/master/google-research/trans
# Reference: Acceda el paquete de herramientas
#
# Source: Wells Fargo Stories
# System: English to Spanish
#
# The following is a list of short stories written by Wells Fargo employees. The stories were written as part of a contest sponsored by Wells Fargo in 2013.
#
# ### "A Day in the Life of a Wells Fargo Stagecoach Driver"
#
# A Day in the Life of a Wells Fargo Stagecoach Driver
#
# In 1860, the Wells Fargo stagecoach was the fastest and safest way to travel across the United States.
#
# Stagecoach drivers faced many dangers on their journe
# Reference: Relatos de Wells Fargo
#
# Source: BANKING SERVICES
# System: English to Spanish
#
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# BANKING SERVICES
#
# Translation: English to Spanish
#
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# BANKING SERVICES
#
# Translation: English to Spanish
#
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# BANKING SERVICES
#
# Translation: English to Spanish
#
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# B
# Reference: SERVICIOS BANCARIOS
#
# Source: DIGITAL BANKING
# System: English:
#
# Digital banking is a type of banking that allows customers to access their accounts and perform transactions online.
#
# Spanish:
#
# La banca digital es un tipo de banca que permite a los clientes acceder a sus cuentas y realizar transacciones en línea.
#
# English:
#
# Digital banking is a type of banking that allows customers to access their accounts and perform transactions online.
#
# Spanish:
#
# La banca digital es un tipo de banca que permite a los clientes acceder a sus cuentas y realizar
# Reference: SERVICIOS BANCARIOS DIGITALES
#
# Source: EDUCATION & TOOLS
# System: https://www.deepl.com/translator
#
# Input: https://www.deepl.com/translator
#
# Output: https://www.deepl.com/translator
# Reference: EDUCACIÓN Y HERRAMIENTAS
#
# Source: Compare checking accounts
# System: Compare checking accounts
#
# Translation: Compare checking accounts
#
# Translation: Compare checking accounts
#
# Translation: Compare checking accounts
#
# Translation: Compare checking accounts
#
# Translation: Compare checking accounts
#
# Translation: Compare checking accounts
#
# Translation: Compare checking accounts
#
# Translation: Compare checking accounts
#
# Translation: Compare checking accounts
#
# Translation: Compare checking accounts
#
# Translation: Compare checking accounts
#
# Translation: Compare checking accounts
#
# Translation: Compare checking accounts
#
# Translation: Compare
# Reference: Compare las cuentas de cheques
#
# Source: Savings & CDs
# System: English to Spanish
#
# Translate from English to Spanish. ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Savings & CDs
#
# Translation:
#
# English to Spanish
#
# Translate from English to Spanish. ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Savings & CDs
#
# Translation:
#
# English to Spanish
#
# Translate from English to Spanish. ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Savings & CDs
#
# Translation:
# Reference: Ahorros y cuentas a plazo (CD)
#
# Source: Credit Cards
# System: Credit Cards
#
# Credit Cards
#
# Credit Cards
#
# Credit Cards
#
# Credit Cards
#
# Credit Cards
#
# Credit Cards
#
# Credit Cards
#
# Credit Cards
#
# Credit Cards
#
# Credit Cards
#
# Credit Cards
#
# Credit Cards
#
# Credit Cards
#
# Credit Cards
#
# Credit Cards
#
# Credit Cards
#
# Credit Cards
#
# Credit Cards
#
# Credit Cards
#
# Credit Cards
# Reference: Tarjetas de crédito
#
# Source: Home Loans
# System: Home Loans
# */
#
# import java.util.Scanner;
#
# public class HomeLoans {
#
#     public static void main(String[] args) {
#         Scanner scanner = new Scanner(System.in);
#
#         System.out.println("Enter the loan amount: ");
#         double loanAmount = scanner.nextDouble();
#
#         System.out.println("Enter the interest rate: ");
#         double interestRate = scanner.nextDouble();
#
#         System.out.println("Enter the loan term: ");
#         double loanTerm = scanner.next
# Reference: Préstamos hipotecarios
#
# Source: Auto Loans
# System: Auto Loans
#
# ## Sentence No. 1:
# El préstamo automotor
#
# ## Sentence No. 2:
# El préstamo automotor
#
# ## Sentence No. 3:
# El préstamo automotor
#
# ## Sentence No. 4:
# El préstamo automotor
#
# ## Sentence No. 5:
# El préstamo automotor
#
# ## Sentence No. 6:
# El préstamo automotor
#
# ## Sentence No. 7:
# El préstamo automot
# Reference: Préstamos para automóviles
#
# Source: Investing
# System: Investing
#
# Translation:
#
# Investing
#
# Translation:
#
# Investing
#
# Translation:
#
# Investing
#
# Translation:
#
# Investing
#
# Translation:
#
# Investing
#
# Translation:
#
# Investing
#
# Translation:
#
# Investing
#
# Translation:
#
# Investing
#
# Translation:
#
# Investing
#
# Translation:
#
# Investing
#
# Translation:
#
# Investing
#
# Translation:
#
# Investing
#
# Trans
# Reference: Inversiones
#
# Source: Small Business
# System: Small Business
#
# Small Business
#
# Small Business
#
# Small Business
#
# Small Business
#
# Small Business
#
# Small Business
#
# Small Business
#
# Small Business
#
# Small Business
#
# Small Business
#
# Small Business
#
# Small Business
#
# Small Business
#
# Small Business
#
# Small Business
#
# Small Business
#
# Small Business
#
# Small Business
#
# Small Business
#
# Small Business
#
# Small Business
#
# Small Business
#
# Small Business
#
# Small Business
#
# Sm
# Reference: Pequeñas empresas
#
# Source: Commercial Banking
# System: English to Spanish
# ===============================================================================
#
# This file is part of a collection of machine translation demonstration datasets.
# For more information, see http://www.statmt.org/wmt16/translation-task.html
# ===============================================================================
# """
#
# from __future__ import print_function
# from __future__ import division
# from __future__ import absolute_import
# from __future__ import unicode_literals
#
# import logging
# import os
# import random
# import re
# import string
# import sys
# import time
# Reference: Banca comercial
#
# Source: Sitemap
# System: English to Spanish
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
# Reference: Mapa del sitio
#
# Source: About Wells Fargo
# System: Wells Fargo is an American international banking and financial services holding company headquartered in San Francisco, California, with "hubquarters" throughout the country. It is the world's second-largest bank by market capitalization and the third-largest bank in the U.S. by total assets. Wells Fargo is the fourth-largest bank in deposits, home mortgage servicing, and debit cards. Wells Fargo's primary U.S. operating subsidiary is national bank Wells Fargo Bank, N.A., which designates its main office
# Reference: Acerca de Wells Fargo
#
# Source: Careers
# System: English to Spanish
#
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Careers
#
# Translation: English to Spanish
#
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Careers
#
# Translation: English to Spanish
#
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Careers
#
# Translation: English to Spanish
#
# ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Careers
#
# Translation: English to Spanish
#
# ONLY OUT
# Reference: Empleo
#
# Source: Diversity and Accessibility
# System: English to Spanish
#
# Translate from English to Spanish. ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Diversity and Accessibility
#
# Translation:
#
# English to Spanish
#
# Translate from English to Spanish. ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Diversity and Accessibility
#
# Translation:
#
# English to Spanish
#
# Translate from English to Spanish. ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
#
# Diversity and Accessibility
#
# Translation:
#
# English to Spanish
# Reference: Diversidad y accesibilidad
#
# Source: Our Wells Fargo Mobile® app gives you fast and secure access to your finances
# System: Our Wells Fargo Mobile® app gives you fast and secure access to your finances
#
# Translate from English to Spanish. ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
# Our Wells Fargo Mobile® app gives you fast and secure access to your finances
#
# Translation: Our Wells Fargo Mobile® app gives you fast and secure access to your finances
#
# Translate from English to Spanish. ONLY OUTPUT THE TRANSLATION TEXT AND STOP:
# Our Wells Fargo Mobile® app gives you fast and secure access to your fin
# Reference: Nuestra app de Wells Fargo Mobile® le ofrece acceso rápido y seguro a sus finanzas
#
# Source: Check your account balance
# System: Check your account balance
#
# Check your account balance
#
# Translation: Check your account balance
#
# Check your account balance
#
# Translation: Check your account balance
#
# Check your account balance
#
# Translation: Check your account balance
#
# Check your account balance
#
# Translation: Check your account balance
#
# Check your account balance
#
# Translation: Check your account balance
#
# Check your account balance
#
# Translation: Check your account balance
#
# Check your account balance
#
# Translation: Check your account balance
#
# Check your account balance
#
# Translation: Check your account balance
#
# Check your
# Reference: Consulte el saldo de su cuenta
#
# Source: View your latest FICO® Score
# System: Your latest FICO® Score is:
#
# Your latest FICO® Score is:
#
# Your latest FICO® Score is:
#
# Your latest FICO® Score is:
#
# Your latest FICO® Score is:
#
# Your latest FICO® Score is:
#
# Your latest FICO® Score is:
#
# Your latest FICO® Score is:
#
# Your latest FICO® Score is:
#
# Your latest FICO® Score is:
#
# Your latest FICO®
# Reference: Vea su Puntuación FICO® Score más reciente
#
# Source: Send and receive money with Zelle®
# System: https://www.google.com/translate?sl=en&tl=es&js=y&prev=_t&hl=en&ie=UTF-8&u=https%3A%2F%2Fwww.zellepay.com%2Fen-us%2Fsend-and-receive-money-with-zelle%2F&edit-text=&sa=X&ved=0ahUKEwjVp56Sq7PLAhWGxYMKHZ1bD4QQ6AEIHTAA
# Reference: Envíe y reciba dinero con Zelle®
#
# Source: Please note that the score provided under this service is for educational purposes and may not be the score used by Wells Fargo to make credit decisions.
# System: English text:
#
# This is a test.
#
# Spanish text:
#
# Este es un test.
#
# Output:
#
# This is a test.
#
# Este es un test.
# \end{code}
#
# Comment: I'm voting to close this question as off-topic because it's not about programming.
#
# Comment: I'm voting to close this question as off-topic because it's not about programming.
#
# Comment: I'm voting to close this question as off-topic because it's not about programming.
#
# Comment: I
# Reference: Tenga en cuenta que la puntuación proporcionada a través de este servicio es para fines educativos y es posible que no sea la puntuación utilizada por Wells Fargo para tomar decisiones de crédito.
#
# Source: Wells Fargo looks at many factors to determine your credit options; therefore, a specific FICO® Score or Wells Fargo credit rating does not guarantee a specific loan rate, approval of a loan, or an upgrade on a credit card.
# System: Wells Fargo looks at many factors to determine your credit options; therefore, a specific FICO® Score or Wells Fargo credit rating does not guarantee a specific loan rate, approval of a loan, or an upgrade on a credit card.
# Reference: Hay muchos factores que Wells Fargo analiza para determinar sus opciones de crédito; por lo tanto, una Puntuación FICO® Score o clasificación de crédito de Wells Fargo específicas no garantizan una tasa de préstamo específica, la aprobación de un préstamo o una mejora de categoría en una tarjeta de crédito.
#
# Summary:
# --------------------------------------------------
# Set 1 BLEU Score: 1.60
# Set 2 BLEU Score: 0.00
# Average BLEU Score: 0.80

# %% [markdown]
# ## Libraries

# %%
# Now check versions
import pkg_resources
import sys

def get_package_details():
    """Print details of specific packages and Python version"""
    packages_to_check = [
        'torch',
        'transformers',
        'sacrebleu',
        'tqdm',
        'numpy',
        'sentencepiece'  # Often used by transformers
    ]

    print("Python version:", sys.version.split()[0])
    print("\nPackage versions:")
    print("-" * 50)

    for package in packages_to_check:
        try:
            version = pkg_resources.get_distribution(package).version
            print(f"{package:<15} {version}")
        except pkg_resources.DistributionNotFound:
            print(f"{package:<15} Not installed")

# Check CUDA availability for PyTorch
import torch
print("\nCUDA Status:")
print("-" * 50)
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
    print(f"Current GPU: {torch.cuda.get_device_name()}")

# Run the check
get_package_details()
# Out:
# CUDA Status:
# --------------------------------------------------
# CUDA available: True
# CUDA version: 12.1
# Current GPU: NVIDIA A100-SXM4-40GB
# Python version: 3.10.12
#
# Package versions:
# --------------------------------------------------
# torch           2.5.1+cu121
# transformers    4.46.2
# sacrebleu       2.4.3
# tqdm            4.66.6
# numpy           1.26.4
# sentencepiece   0.2.0
# <ipython-input-12-7f5467e83d8f>:2: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources
