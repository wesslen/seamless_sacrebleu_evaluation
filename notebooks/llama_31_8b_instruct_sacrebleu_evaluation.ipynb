# %% [markdown]
# <a href="https://colab.research.google.com/github/wesslen/seamless_sacrebleu_evaluation/blob/main/notebooks/llama_31_8b_instruct_sacrebleu_evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !uv pip install --system transformers sacrebleu tqdm torch
# Out:
# Using Python 3.10.12 environment at /usr
# Resolved 28 packages in 321ms
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# portalocker ------------------------------     0 B/19.12 KiB
# ⠙ Preparing packages... (0/3)
# portalocker ------------------------------ 14.91 KiB/19.12 KiB
# ⠙ Preparing packages... (0/3)
# portalocker ------------------------------ 14.91 KiB/19.12 KiB
# ⠙ Preparing packages... (0/3)
# portalocker ------------------------------ 19.12 KiB/19.12 KiB
# ⠙ Preparing packages... (0/3)
# portalocker ------------------------------ 19.12 KiB/19.12 KiB
# colorama   ------------------------------ 16.00 KiB/24.74 KiB
# ⠙ Preparing packages... (0/3)
# portalocker ------------------------------ 19.12 KiB/19.12 KiB
# colorama   ------------------------------ 16.00 KiB/24.74 KiB
# ⠙ Preparing packages... (0/3)
# portalocker ------------------------------ 19.12 KiB/19.12 KiB
# colorama   ------------------------------ 16.00 KiB/24.74 KiB
# ⠙ Preparing packages... (0/3)
# portalocker ------------------------------ 19.12 KiB/19.12 KiB
# colorama   ------------------------------ 24.74 KiB/24.74 KiB
# ⠙ Preparing packages... (0/3)
# colorama   ------------------------------ 24.74 KiB/24.74 KiB
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# ⠙ Preparing packages... (0/3)
# Prepared 3 packages in 25ms
# Installed 3 packages in 4ms
#  + colorama==0.4.6
#  + portalocker==3.0.0
#  + sacrebleu==2.4.3

# %%
import os
from google.colab import userdata

os.environ['HF_TOKEN'] = userdata.get('huggingface')

# %%
# !huggingface-cli login --token $HF_TOKEN
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# The token `colab` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from sacrebleu.metrics import BLEU
from typing import List, Union, Optional, Dict, Tuple
from dataclasses import dataclass
import tqdm
import logging

# Setup logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

@dataclass
class Llama31Config:
    """Configuration for Llama 3.1 specific settings"""
    # Supported languages by Llama 3.1
    SUPPORTED_LANGUAGES = {
        "English": "eng", "Spanish": "spa", "French": "fra",
        "German": "deu", "Italian": "ita", "Portuguese": "por",
        "Hindi": "hin", "Thai": "tha"
    }

    system_prompt: str = """You are a professional translator with expertise in multiple languages.
    You will now translate text between languages. Only provide the translation with no explanations."""

    # Updated template using correct Llama 3.1 tokens
    chat_template: str = (
        "<|begin_of_text|>"
        "<|start_header_id|>system<|end_header_id|>\n{system_prompt}<|eot_id|>"
        "<|start_header_id|>user<|end_header_id|>\n{user_prompt}<|eot_id|>"
        "<|start_header_id|>assistant<|end_header_id|>\n"
    )

    def format_prompt(self, text: str, src_lang: str, tgt_lang: str) -> str:
        """Format the translation prompt according to Llama 3.1 template"""
        user_prompt = f"Translate this {src_lang} text to {tgt_lang}:\n{text}"
        return self.chat_template.format(
            system_prompt=self.system_prompt,
            user_prompt=user_prompt
        )

class Llama31TranslationEvaluator:
    def __init__(
        self,
        model_name: str = "meta-llama/Llama-3.1-8B-Instruct",
        device: str = "cuda" if torch.cuda.is_available() else "cpu",
        debug: bool = False
    ):
        """Initialize the translation evaluator with Llama 3.1."""
        self.debug = debug
        logger.info(f"Using device: {device}")
        self.device = device
        self.llama_config = Llama31Config()

        logger.info("Loading model and tokenizer...")
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)

        # Handle tokenizer settings
        if self.tokenizer.pad_token is None:
            self.tokenizer.pad_token = self.tokenizer.eos_token
        self.tokenizer.padding_side = "left"

        self.model = AutoModelForCausalLM.from_pretrained(
            model_name,
            torch_dtype=torch.float16 if device == "cuda" else torch.float32,
            device_map="auto"
        )

        self.bleu = BLEU()
        logger.info("Setup complete!")

    def _extract_translation(self, full_text: str, prompt: str) -> Tuple[str, dict]:
        """Extract translation from model output with detailed debug info."""
        debug_info = {
            "full_text_len": len(full_text),
            "prompt_len": len(prompt),
            "has_assistant_header": "<|start_header_id|>assistant<|end_header_id|>" in full_text,
            "has_eot": "<|eot_id|>" in full_text
        }

        # Try to find the assistant's response section
        assistant_marker = "<|start_header_id|>assistant<|end_header_id|>"
        response_start = full_text.find(assistant_marker)

        if response_start != -1:
            # Extract text after the assistant marker
            response = full_text[response_start + len(assistant_marker):]

            # Remove any trailing special tokens
            response = response.replace("<|eot_id|>", "").replace("<|eom_id|>", "")
            response = response.replace("<|end_of_text|>", "").strip()

            debug_info["extraction_method"] = "assistant_marker"
        else:
            # Fallback: try to extract everything after the prompt
            response = full_text[len(prompt):].strip()
            debug_info["extraction_method"] = "prompt_removal"

        # Clean any remaining special tokens
        response = response.replace("<s>", "").replace("</s>", "").strip()
        debug_info["final_response_len"] = len(response)

        return response, debug_info

    def translate_batch(
        self,
        texts: List[str],
        config: TranslationConfig,
        batch_size: int = 1  # Reduced batch size for better reliability
    ) -> List[str]:
        """Translate a list of texts in batches."""
        if config.src_lang not in self.llama_config.SUPPORTED_LANGUAGES.keys() or \
           config.tgt_lang not in self.llama_config.SUPPORTED_LANGUAGES.keys():
            raise ValueError(f"Language must be one of {list(self.llama_config.SUPPORTED_LANGUAGES.keys())}")

        translations = []

        # Process in batches
        for i in tqdm.trange(0, len(texts), batch_size, desc="Translating"):
            batch = texts[i:i + batch_size]
            batch_prompts = [
                self.llama_config.format_prompt(
                    text=text,
                    src_lang=config.src_lang,
                    tgt_lang=config.tgt_lang
                ) for text in batch
            ]

            if self.debug:
                logger.info(f"Sample prompt:\n{batch_prompts[0]}")

            # Process input
            inputs = self.tokenizer(
                batch_prompts,
                return_tensors="pt",
                padding=True,
                truncation=True,
                max_length=2048
            ).to(self.device)

            # Generate translations
            generation_config = {
                "max_new_tokens": config.max_new_tokens,
                "num_beams": config.num_beams,
                "temperature": config.temperature,
                "top_p": config.top_p,
                "top_k": config.top_k,
                "repetition_penalty": config.repetition_penalty,
                "pad_token_id": self.tokenizer.pad_token_id,
                "eos_token_id": self.tokenizer.eos_token_id,
                "do_sample": config.temperature > 0,
            }

            with torch.no_grad():
                outputs = self.model.generate(
                    **inputs,
                    **generation_config
                )

            # Decode translations
            batch_translations = []
            for output, prompt in zip(outputs, batch_prompts):
                full_text = self.tokenizer.decode(output, skip_special_tokens=False)
                translation, debug_info = self._extract_translation(full_text, prompt)

                if self.debug:
                    logger.info(f"Translation debug info: {debug_info}")
                    logger.info(f"Raw output: {full_text}")
                    logger.info(f"Extracted translation: {translation}")

                if not translation.strip():
                    logger.warning("Empty translation detected!")
                    logger.info(f"Full text: {full_text}")

                batch_translations.append(translation)

            translations.extend(batch_translations)

        return translations

    def evaluate_translations(
        self,
        hypotheses: List[str],
        references: Union[List[str], List[List[str]]],
        verbose: bool = True
    ) -> BLEU:
        """Evaluate translations using sacreBLEU."""
        if isinstance(references[0], str):
            references = [[ref] for ref in references]

        bleu_score = self.bleu.corpus_score(hypotheses, references)

        if verbose:
            print(f"BLEU score: {bleu_score.score:.2f}")
            print(f"Signature: {self.bleu.get_signature()}")

        return bleu_score

# %%
# Test data
source_texts = [
    "Hello, my dog is cute",
    "The weather is nice today",
    "I love programming"
]

# Reference translations in French
references = [
    ["Bonjour, mon chien est mignon"],
    ["Le temps est beau aujourd'hui"],
    ["J'aime la programmation"]
]

print("Initializing translator...")
# Initialize evaluator
evaluator = Llama31TranslationEvaluator(model_name="meta-llama/Llama-3.1-8B-Instruct")

config = TranslationConfig.from_preset(
    preset="sampling",
    src_lang="English",
    tgt_lang="French"
)

print("\nTranslating texts...")
# Translate
translations = evaluator.translate_batch(
    texts=source_texts,
    config=config,
    batch_size=1
)

# Evaluate
print("\nEvaluating translations...")
bleu_score = evaluator.evaluate_translations(
    hypotheses=translations,
    references=references
)

# Print results
print(f"\nDetailed Results for examples:")
print("-" * 50)
for src, hyp, ref in zip(source_texts, translations, references):
    print(f"\nSource: {src}")
    print(f"System: {hyp}")
    print(f"Reference: {ref[0]}")
# Out:
# Initializing translator...
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Translating texts...
# Translating: 100%|██████████| 3/3 [00:01<00:00,  2.62it/s]
# Evaluating translations...
# BLEU score: 80.91
# Signature: nrefs:3|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.3
#
# Detailed Results for examples:
# --------------------------------------------------
#
# Source: Hello, my dog is cute
# System: Bonjour, mon chien est mignon.
# Reference: Bonjour, mon chien est mignon
#
# Source: The weather is nice today
# System: Le temps est agréable aujourd'hui.
# Reference: Le temps est beau aujourd'hui
#
# Source: I love programming
# System: J'adore le programmation
# Reference: J'aime la programmation

# %%
import json

def run_evaluation(
    jsonl_files: List[str],
    src_lang: str = "English",
    tgt_lang: str = "Spanish",
    model_name: str = "meta-llama/Llama-3.1-8B-Instruct",
    batch_size: int = 4,
    generation_preset: str = "quality"
):
    """Run evaluation pipeline."""
    print(f"\nInitializing Llama 3.1 translator...")
    evaluator = Llama31TranslationEvaluator(model_name=model_name)

    config = TranslationConfig.from_preset(
        preset=generation_preset,
        src_lang=src_lang,
        tgt_lang=tgt_lang
    )

    all_bleu_scores = []

    for file_path in jsonl_files:
        print(f"\nProcessing file: {file_path}")

        # Load data
        mapping = read_jsonl(file_path)
        source_texts = [item["source_text"] for item in mapping]
        references = [item["references"] for item in mapping]

        # Translate
        translations = evaluator.translate_batch(
            texts=source_texts,
            config=config,
            batch_size=batch_size
        )

        # Evaluate
        bleu_score = evaluator.evaluate_translations(
            hypotheses=translations,
            references=references
        )

        all_bleu_scores.append(bleu_score.score)

        # Print results
        print(f"\nDetailed Results for {file_path}:")
        print("-" * 50)
        for src, hyp, ref in zip(source_texts, translations, references):
            print(f"\nSource: {src}")
            print(f"System: {hyp}")
            print(f"Reference: {ref[0]}")

    print("\nSummary:")
    print("-" * 50)
    for file_path, score in zip(jsonl_files, all_bleu_scores):
        print(f"{file_path}: BLEU = {score:.2f}")
    print(f"Average BLEU Score: {sum(all_bleu_scores) / len(all_bleu_scores):.2f}")

# Utility function for reading JSONL files
def read_jsonl(file_path: str) -> List[Dict]:
    """Read JSONL file and return parsed data."""
    data = []
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            try:
                data.append(json.loads(line.strip()))
            except json.JSONDecodeError as e:
                print(f"Error parsing line: {e}")
    return data

# %%
# !wget https://github.com/wesslen/seamless_sacrebleu_evaluation/raw/main/data/01-english-spanish-mapping.jsonl
# !wget https://github.com/wesslen/seamless_sacrebleu_evaluation/raw/main/data/02-english-spanish-mapping.jsonl
# Out:
# --2024-12-01 15:48:27--  https://github.com/wesslen/seamless_sacrebleu_evaluation/raw/main/data/01-english-spanish-mapping.jsonl
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/wesslen/seamless_sacrebleu_evaluation/main/data/01-english-spanish-mapping.jsonl [following]
# --2024-12-01 15:48:27--  https://raw.githubusercontent.com/wesslen/seamless_sacrebleu_evaluation/main/data/01-english-spanish-mapping.jsonl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2829 (2.8K) [text/plain]
# Saving to: ‘01-english-spanish-mapping.jsonl’
#
# 01-english-spanish- 100%[===================>]   2.76K  --.-KB/s    in 0s
#
# 2024-12-01 15:48:27 (53.8 MB/s) - ‘01-english-spanish-mapping.jsonl’ saved [2829/2829]
#
# --2024-12-01 15:48:27--  https://github.com/wesslen/seamless_sacrebleu_evaluation/raw/main/data/02-english-spanish-mapping.jsonl
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/wesslen/seamless_sacrebleu_evaluation/main/data/02-english-spanish-mapping.jsonl [following]
# --2024-12-01 15:48:28--  https://raw.githubusercontent.com/wesslen/seamless_sacrebleu_evaluation/main/data/02-english-spanish-mapping.jsonl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12284 (12K) [text/plain]
# Saving to: ‘02-english-spanish-mapping.jsonl’
#
# 02-english-spanish- 100%[===================>]  12.00K  --.-KB/s    in 0s
#
# 2024-12-01 15:48:28 (122 MB/s) - ‘02-english-spanish-mapping.jsonl’ saved [12284/12284]

# %%
jsonl_files = [
    "01-english-spanish-mapping.jsonl",
    "02-english-spanish-mapping.jsonl"
]

run_evaluation(
    jsonl_files=jsonl_files,
    src_lang="English",
    tgt_lang="Spanish",
    model_name="meta-llama/Llama-3.1-8B-Instruct",
    generation_preset="quality"
)
# Out:
# Initializing Llama 3.1 translator...
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Processing file: 01-english-spanish-mapping.jsonl
# Translating: 100%|██████████| 8/8 [00:06<00:00,  1.31it/s]
# BLEU score: 46.71
# Signature: nrefs:31|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.3
#
# Detailed Results for 01-english-spanish-mapping.jsonl:
# --------------------------------------------------
#
# Source: Wells Fargo Bank | Financial Services & Online Banking
# System: Banco Wells Fargo | Servicios Financieros y Banca en Línea
# Reference: Wells Fargo Bank | Servicios Financieros y Banca por Internet
#
# Source: How can we help?
# System: ¿En qué podemos ayudar?
# Reference: ¿Cómo podemos ayudarle?
#
# Source: Popular FAQs
# System: Preguntas frecuentes
# Reference: Preguntas frecuentes populares
#
# Source: How do I find my routing and account numbers?
# System: ¿Cómo puedo encontrar mis números de ruta y cuenta?
# Reference: ¿Cómo puedo encontrar mis números de ruta y de cuenta?
#
# Source: Is there a fee for Zelle®?
# System: ¿Hay una tarifa para Zelle?
# Reference: ¿Se aplica algún cargo por usar Zelle®?
#
# Source: How do I report suspected fraud?
# System: ¿Cómo denunciar un fraude sospechoso?
# Reference: ¿Qué debo hacer para reportar una sospecha de fraude?
#
# Source: See more FAQs
# System: Ver más preguntas frecuentes
# Reference: Ver más preguntas frecuentes
#
# Source: Find a location
# System: Encuentra un lugar
# Reference: Busque ATM/sucursal
#
# Source: Make an appointment
# System: Hacer una cita
# Reference: Haga una cita
#
# Source: Quick help
# System: Ayuda rápida
# Reference: Ayuda rápida
#
# Source: Customer service and FAQs
# System: Servicio al cliente y preguntas frecuentes
# Reference: Servicio al cliente y preguntas frecuentes
#
# Source: Security and fraud
# System: Seguridad y fraude
# Reference: Seguridad y fraude
#
# Source: Global remittance
# System: Remesas globales
# Reference: Remesas globales
#
# Source: Foreign exchange
# System: Intercambio de divisas
# Reference: Cambio de moneda extranjera
#
# Source: Activate debit card
# System: Activar la tarjeta de débito
# Reference: Activación inicial de tarjeta de débito
#
# Source: Transfer and pay
# System: Trasladar y pagar
# Reference: Transfiera y pague
#
# Source: Report fraud
# System: Denunciar fraude
# Reference: Reporte el fraude
#
# Source: Find routing and account numbers
# System: Encuentre números de ruta y de cuenta
# Reference: Encuentre los números de ruta y de cuenta
#
# Source: Checking FAQs
# System: Verificando Preguntas Frecuentes
# Reference: Preguntas frecuentes sobre cuentas de cheques
#
# Source: Good evening
# System: Buenas noches
# Reference: Buenas noches
#
# Source: Sign on to manage your accounts
# System: Iniciar sesión para administrar tus cuentas
# Reference: Inicie sesión para administrar sus cuentas
#
# Source: Username
# System: Nombre de usuario
# Reference: Usuario
#
# Source: Password
# System: Contraseña
# Reference: Contraseña
#
# Source: Save username
# System: Guardar nombre de usuario
# Reference: Guarde el usuario
#
# Source: Notice
# System: Aviso
# Reference: Aviso
#
# Source: For your security, we do not recommend using this feature on a shared device.
# System: Para su seguridad, no recomendamos utilizar esta función en un dispositivo compartido.
# Reference: Por su seguridad, no recomendamos usar esta función en un dispositivo compartido.
#
# Source: Enroll
# System: Inscribirse
# Reference: Inscríbase
#
# Source: Forgot username or password?
# System: ¿Olvidó su nombre de usuario o contraseña?
# Reference: ¿Olvidó su usuario o contraseña?
#
# Source: Security Center
# System: Centro de Seguridad
# Reference: Centro de seguridad
#
# Source: Privacy, Cookies, and Legal
# System: Privacidad, Cookies y Términos legales
# Reference: Privacidad, cookies y asuntos legales
#
# Source: Screen image simulated.
# System: Imagen de pantalla simulada.
# Reference: La imagen en pantalla es simulada.
#
# Processing file: 02-english-spanish-mapping.jsonl
# Translating: 100%|██████████| 24/24 [00:29<00:00,  1.23s/it]
# BLEU score: 14.06
# Signature: nrefs:96|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.3
#
# Detailed Results for 02-english-spanish-mapping.jsonl:
# --------------------------------------------------
#
# Source: Say hello to convenient checking
# System: Saludos a la verificación conveniente
# Reference: Hola a una cuenta de cheques conveniente
#
# Source: Explore our checking options and choose the right account for you
# System: Explora nuestras opciones de cheques y elija la cuenta adecuada para ti
# Reference: Explore nuestras opciones de cuentas de cheques y elija la adecuada para usted
#
# Source: Get started
# System: Comencemos
# Reference: Para comenzar
#
# Source: Find mortgage happiness
# System: Encuentra la felicidad hipotecaria
# Reference: Sienta alegría hipotecaria
#
# Source: With a down payment as low as 3%
# System: Con un pago inicial tan bajo como el 3%
# Reference: Con un pago inicial bajo, desde tan solo el 3%
#
# Source: Learn more
# System: Aprende más
# Reference: Más información
#
# Source: Unlock convenient checking
# System: Desbloquear verificación conveniente
# Reference: Acceda una cuenta de cheques conveniente
#
# Source: Find a credit card
# System: Encuentre una tarjeta de crédito
# Reference: Encuentre una tarjeta de crédito
#
# Source: Low intro rate, cash back, rewards and more
# System: Tasa de introducción baja, reembolso en efectivo, recompensas y más
# Reference: Baja tasa intro, recompensas en efectivo y más
#
# Source: Interest rates today
# System: Tasas de interés de hoy
# Reference: Tasas de interés hoy
#
# Source: Check rates
# System: Verificar tarifas
# Reference: Consulte las tasas
#
# Source: A home of your own
# System: Una casa propia
# Reference: Una casa propia
#
# Source: With low down payment options on a fixed-rate mortgage
# System: Con opciones de pago inicial bajo en un préstamo hipotecario a tipo de interés fijo
# Reference: Con opciones de pago inicial bajo en hipotecas de tasa fija
#
# Source: Financial guidance and support
# System: Asesoramiento y apoyo financiero
# Reference: Apoyo y orientación financieros
#
# Source: Save. Invest. Retire well.
# System: Ahorrar. Invertir. Retirarse con bienestar.
# Reference: Ahorre. Invierta. Jubílese bien.
#
# Source: Discover how to start saving to meet your retirement goals
# System: Descubre cómo empezar a ahorrar para alcanzar tus metas de jubilación
# Reference: Descubra cómo comenzar a ahorrar para cumplir sus metas para la jubilación
#
# Source: Reduce debt. Build credit. Enjoy life.
# System: Reduzca la deuda. Construya crédito. Disfrute de la vida.
# Reference: Menor deuda. Mejor crédito. Viva la vida.
#
# Source: Banking in the palm of your hand
# System: Banca en la palma de tu mano
# Reference: Servicios bancarios en la palma de su mano
#
# Source: Our Wells Fargo Mobile® app gives you fast and secure access to your finances
# System: Nuestra aplicación móvil de Wells Fargo te da acceso rápido y seguro a tus finanzas
# Reference: Nuestra app de Wells Fargo Mobile® le ofrece acceso rápido y seguro a sus finanzas
#
# Source: Check your account balance
# System: Verifique su saldo de cuenta
# Reference: Consulte el saldo de su cuenta
#
# Source: View your latest FICO® Score
# System: Ver su puntaje FICO® más reciente
# Reference: Vea su Puntuación FICO® Score más reciente
#
# Source: Send and receive money with Zelle®
# System: Enviar y recibir dinero con Zelle®
# Reference: Envíe y reciba dinero con Zelle®
#
# Source: Download our app
# System: Descargue nuestra aplicación
# Reference: Descargue nuestra app
#
# Source: Serving our customers and communities
# System: Atendiendo a nuestros clientes y comunidades
# Reference: Sirviendo a nuestros clientes y a nuestras comunidades
#
# Source: It doesn't happen with one transaction, in one day on the job, or in one quarter. It's earned relationship by relationship.
# System: No sucede con una transacción, en un día de trabajo o en un trimestre. Se gana con relación a relación.
# Reference: Eso no ocurre con una transacción, en un día de trabajo ni en un trimestre. Se logra relación por relación.
#
# Source: Who we are
# System: ¿Quiénes somos
# Reference: Quiénes somos
#
# Source: Wells Fargo helps strengthen communities through diversity, equity, and inclusion, economic empowerment, and sustainability.
# System: Wells Fargo ayuda a fortalecer las comunidades a través de la diversidad, la equidad y la inclusión, el empoderamiento económico y la sostenibilidad.
# Reference: Wells Fargo ayuda a fortalecer a las comunidades mediante la diversidad, la equidad, la inclusión, el fortalecimiento económico y la sustentabilidad.
#
# Source: Why we're committed to communities
# System: Estamos comprometidos con las comunidades
# Reference: Por qué hemos asumido un compromiso con las comunidades
#
# Source: We don't just serve our communities—we are our communities.
# System: No sólo servimos a nuestras comunidades, somos nuestras comunidades.
# Reference: No solo les prestamos servicios a nuestras comunidades; somos nuestras comunidades.
#
# Source: We're committed to helping customers and neighborhoods across the country thrive.
# System: Estamos comprometidos con ayudar a los clientes y a las comunidades en todo el país a prosperar.
# Reference: Hemos asumido el compromiso de ayudar a que clientes y vecindarios en todo el país prosperen.
#
# Source: Clear Access Banking
# System: Acceso Claro a la Banca
# Reference: Cuenta Clear Access Banking
#
# Source: An account that helps you spend only what you have in it
# System: Una cuenta que te ayuda a gastar solo lo que tienes en ella.
# Reference: Una cuenta que le ayuda a gastar solo lo que tiene en ella
#
# Source: Prime Checking
# System: Verificación Primaria
# Reference: Cuenta de Cheques Prime Checking
#
# Source: Many discounts and benefits are included with this interest-bearing account
# System: Muchos descuentos y beneficios están incluidos con este cuenta con interés.
# Reference: Se incluyen muchos descuentos y beneficios con esta cuenta que produce intereses
#
# Source: Everyday Checking
# System: Verificación Diaria
# Reference: Cuenta de Cheques Everyday Checking
#
# Source: Our most popular account for managing day-to-day financial needs
# System: Nuestra cuenta más popular para gestionar necesidades financieras diarias
# Reference: Nuestra cuenta más popular para administrar las necesidades financieras diarias
#
# Source: Premier Checking
# System: Cuenta Premier
# Reference: Cuenta de Cheques Premier Checking
#
# Source: An interest-bearing account with our premier level of relationship banking benefits
# System: Cuenta con interés con nuestros beneficios de banca de relación de nivel premier
# Reference: Una cuenta que produce intereses, con nuestro nivel Premier de beneficios bancarios por relación
#
# Source: Student/teen banking
# System: Banco para estudiantes/jóvenes
# Reference: Servicios bancarios para adolescentes y estudiantes
#
# Source: Account options ideal for teens and students
# System: Opciones de cuenta ideales para adolescentes y estudiantes
# Reference: Opciones de cuentas ideales para adolescentes y estudiantes
#
# Source: Way2Save® Savings
# System: Ahorro Way2Save
# Reference: Cuenta de Ahorros Way2Save® Savings
#
# Source: Build your savings automatically
# System: Construye tus ahorros automáticamente
# Reference: Construya sus ahorros automáticamente
#
# Source: Platinum Savings
# System: Ahorro de Platino
# Reference: Cuenta de Ahorros Platinum Savings
#
# Source: Grow your savings with more ways to access your money
# System: Aumenta tus ahorros con más formas de acceder a tu dinero
# Reference: Haga crecer sus ahorros con más maneras de acceder a su dinero
#
# Source: Wells Fargo CDs
# System: Certificados de Depósito a Plazo Fijo de Wells Fargo
# Reference: Certificados de depósito (CD) de Wells Fargo
#
# Source: Provide a guaranteed rate of return, even during uncertain times
# System: Proporcionar una tasa de retorno garantizada, incluso en tiempos inciertos
# Reference: Ofrece una tasa de retorno garantizada, incluso en momentos de incertidumbre
#
# Source: Kids Savings
# System: Ahorro Infantil
# Reference: Ahorros para niños
#
# Source: A good way to start your children on the road to financial success
# System: Una buena manera de iniciar a tus hijos en el camino hacia el éxito financiero
# Reference: Una buena manera de comenzar a guiar a sus hijos por el camino hacia el éxito financiero
#
# Source: Cash back credit cards
# System: Tarjetas de crédito con devolución de efectivo
# Reference: Tarjetas de crédito de devolución en efectivo (cash back)
#
# Source: Rewards credit cards
# System: Tarjetas de recompensa
# Reference: Tarjetas de crédito de recompensas
#
# Source: 0% intro APR credit cards
# System: Tarjetas de crédito con 0% de tasa de interés anual (APR)
# Reference: Tarjetas de crédito con tasa APR introductoria del 0%
#
# Source: Travel credit cards
# System: Tarjetas de crédito de viaje
# Reference: Tarjetas de crédito para viajes
#
# Source: Balance transfer credit cards
# System: Tarjetas de crédito de transferencia de saldo
# Reference: Tarjetas de crédito de transferencia de saldo
#
# Source: Buy a home
# System: Comprar una casa
# Reference: Compre una vivienda
#
# Source: Get started on your homeownership journey
# System: Comience su viaje hacia la propiedad de su hogar
# Reference: Comience su camino para ser propietario de vivienda
#
# Source: Refinance your mortgage
# System: Refinanciar su hipoteca
# Reference: Refinancie su préstamo hipotecario
#
# Source: Do home repairs, reduce payments, or more
# System: Haz reparaciones en casa, reduce pagos, o más
# Reference: Haga reparaciones en la vivienda, reduzca los pagos o más
#
# Source: First-time home buyers
# System: Compradores de casas por primera vez
# Reference: Compradores de casa por primera vez
#
# Source: See low down payment options and key steps
# System: Ver opciones de pago con baja cuota y pasos clave
# Reference: Consulte opciones de pago inicial bajo y pasos clave
#
# Source: You must be the primary account holder of an eligible Wells Fargo consumer account with a FICO® Score available, and enrolled in Wells Fargo Online®.
# System: Debes ser el titular principal de una cuenta de consumidor de Wells Fargo elegible con un puntaje FICO® disponible, y estar inscrito en Wells Fargo Online®.
# Reference: Usted debe ser el titular principal de una cuenta al consumidor de Wells Fargo elegible con una Puntuación FICO® Score disponible, y estar inscrito en la Banca por Internet Wells Fargo Online®.
#
# Source: The assistance is provided at no cost.
# System: La asistencia se proporciona sin costo.
# Reference: No se cobra ningún cargo por esta asistencia.
#
# Source: Continue
# System: Continuar
# Reference: Continúe
#
# Source: Cancel
# System: Cancelar
# Reference: Cancele
#
# Source: You are leaving the Wells Fargo website
# System: Estás saliendo del sitio web de Wells Fargo
# Reference: Está saliendo del sitio Web de Wells Fargo
#
# Source: You are leaving wellsfargo.com and entering a website that Wells Fargo does not control.
# System: Está saliendo de wells Fargo.com y entrando en un sitio web que Wells Fargo no controla.
# Reference: Está saliendo de wellsfargo.com y está ingresando en un sitio Web que Wells Fargo no controla.
#
# Source: Wells Fargo has provided this link for your convenience, but does not endorse and is not responsible for the products, services, content, links, privacy policy, or security policy of this website.
# System: Wells Fargo ha proporcionado este enlace para su conveniencia, pero no lo endosa ni es responsable de los productos, servicios, contenido, enlaces, política de privacidad o política de seguridad de este sitio web.
# Reference: Wells Fargo ha proporcionado este enlace para su comodidad, pero no avala ni se hace responsable de los productos, los servicios, el contenido, los enlaces, la política de privacidad ni la política de seguridad de este sitio Web.
#
# Source: City, State or ZIP
# System: Ciudad, Estado o Código Postal
# Reference: Código postal o ciudad y estado
#
# Source: Go
# System: Vaya
# Reference: Ir
#
# Source: Tools
# System: Herramientas
# Reference: Herramientas
#
# Source: Tips
# System: Consejos
# Reference: Sugerencias
#
# Source: Peace of mind
# System: Paz de espíritu
# Reference: Tranquilidad
#
# Source: Get tools. Get tips. Get peace of mind.
# System: Obtén herramientas. Obtén consejos. Obtén tranquilidad de espíritu.
# Reference: Herramientas. Sugerencias. Tranquilidad.
#
# Source: Discover digital tools to help you budget, save, manage credit, and more
# System: Descubre herramientas digitales para ayudarte a presupuestar, ahorrar, gestionar tu crédito y más
# Reference: Herramientas digitales para presupuestar, ahorrar, administrar el crédito y más
#
# Source: Access the toolkit
# System: Acceda a la herramienta
# Reference: Acceda el paquete de herramientas
#
# Source: Wells Fargo Stories
# System: Historias de Wells Fargo
# Reference: Relatos de Wells Fargo
#
# Source: BANKING SERVICES
# System: SERVICIOS BANCARIOS
# Reference: SERVICIOS BANCARIOS
#
# Source: DIGITAL BANKING
# System: BANCA DIGITAL
# Reference: SERVICIOS BANCARIOS DIGITALES
#
# Source: EDUCATION & TOOLS
# System: EDUCACIÓN & HERRAMIENTAS
# Reference: EDUCACIÓN Y HERRAMIENTAS
#
# Source: Compare checking accounts
# System: Cuentas de cheques
# Reference: Compare las cuentas de cheques
#
# Source: Savings & CDs
# System: Ahorros y Cajas de Ahorro
# Reference: Ahorros y cuentas a plazo (CD)
#
# Source: Credit Cards
# System: Tarjetas de Crédito
# Reference: Tarjetas de crédito
#
# Source: Home Loans
# System: Préstamos Hipotecarios
# Reference: Préstamos hipotecarios
#
# Source: Auto Loans
# System: Préstamos de Automóviles
# Reference: Préstamos para automóviles
#
# Source: Investing
# System: Inversión
# Reference: Inversiones
#
# Source: Small Business
# System: Pequeña empresa
# Reference: Pequeñas empresas
#
# Source: Commercial Banking
# System: Banca Comercial
# Reference: Banca comercial
#
# Source: Sitemap
# System: Mapa del sitio
# Reference: Mapa del sitio
#
# Source: About Wells Fargo
# System: Sobre Wells Fargo
# Reference: Acerca de Wells Fargo
#
# Source: Careers
# System: Carreras
# Reference: Empleo
#
# Source: Diversity and Accessibility
# System: Diversidad y Accesibilidad
# Reference: Diversidad y accesibilidad
#
# Source: Our Wells Fargo Mobile® app gives you fast and secure access to your finances
# System: Nuestra aplicación móvil de Wells Fargo te da acceso rápido y seguro a tus finanzas
# Reference: Nuestra app de Wells Fargo Mobile® le ofrece acceso rápido y seguro a sus finanzas
#
# Source: Check your account balance
# System: Verifique su saldo de cuenta
# Reference: Consulte el saldo de su cuenta
#
# Source: View your latest FICO® Score
# System: Ver su puntaje FICO® más reciente
# Reference: Vea su Puntuación FICO® Score más reciente
#
# Source: Send and receive money with Zelle®
# System: Enviar y recibir dinero con Zelle®
# Reference: Envíe y reciba dinero con Zelle®
#
# Source: Please note that the score provided under this service is for educational purposes and may not be the score used by Wells Fargo to make credit decisions.
# System: Tenga en cuenta que la puntuación proporcionada bajo este servicio es para fines educativos y puede no ser la puntuación utilizada por Wells Fargo para tomar decisiones de crédito.
# Reference: Tenga en cuenta que la puntuación proporcionada a través de este servicio es para fines educativos y es posible que no sea la puntuación utilizada por Wells Fargo para tomar decisiones de crédito.
#
# Source: Wells Fargo looks at many factors to determine your credit options; therefore, a specific FICO® Score or Wells Fargo credit rating does not guarantee a specific loan rate, approval of a loan, or an upgrade on a credit card.
# System: Wells Fargo considera muchos factores para determinar sus opciones de crédito; por lo tanto, un puntaje FICO específico o una calificación de crédito de Wells Fargo no garantiza una tasa de préstamo específica, la aprobación de un préstamo o una mejora en una tarjeta de crédito.
# Reference: Hay muchos factores que Wells Fargo analiza para determinar sus opciones de crédito; por lo tanto, una Puntuación FICO® Score o clasificación de crédito de Wells Fargo específicas no garantizan una tasa de préstamo específica, la aprobación de un préstamo o una mejora de categoría en una tarjeta de crédito.
#
# Summary:
# --------------------------------------------------
# 01-english-spanish-mapping.jsonl: BLEU = 46.71
# 02-english-spanish-mapping.jsonl: BLEU = 14.06
# Average BLEU Score: 30.39

# %% [markdown]
# ## Libraries

# %%
# Now check versions
import pkg_resources
import sys

def get_package_details():
    """Print details of specific packages and Python version"""
    packages_to_check = [
        'torch',
        'transformers',
        'sacrebleu',
        'tqdm',
        'numpy',
        'sentencepiece'  # Often used by transformers
    ]

    print("Python version:", sys.version.split()[0])
    print("\nPackage versions:")
    print("-" * 50)

    for package in packages_to_check:
        try:
            version = pkg_resources.get_distribution(package).version
            print(f"{package:<15} {version}")
        except pkg_resources.DistributionNotFound:
            print(f"{package:<15} Not installed")

# Check CUDA availability for PyTorch
import torch
print("\nCUDA Status:")
print("-" * 50)
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
    print(f"Current GPU: {torch.cuda.get_device_name()}")

# Run the check
get_package_details()
# Out:
# CUDA Status:
# --------------------------------------------------
# CUDA available: True
# CUDA version: 12.1
# Current GPU: NVIDIA A100-SXM4-40GB
# Python version: 3.10.12
#
# Package versions:
# --------------------------------------------------
# torch           2.5.1+cu121
# transformers    4.46.2
# sacrebleu       2.4.3
# tqdm            4.66.6
# numpy           1.26.4
# sentencepiece   0.2.0
# <ipython-input-18-7f5467e83d8f>:2: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources
